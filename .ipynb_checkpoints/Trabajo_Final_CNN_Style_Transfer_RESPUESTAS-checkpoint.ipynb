# %% [markdown]
# # Style Transfer
#
# <img src="https://i0.wp.com/chelseatroy.com/wp-content/uploads/2018/12/neural_style_transfer.png?resize=768%2C311&ssl=1">
#
# La idea de este trabajo final es reproducir el siguiente paper:
#
# https://arxiv.org/pdf/1508.06576.pdf
#
# El objetivo es transferir el estilo de una imagen dada a otra imagen distinta.
#
# Como hemos visto en clase, las primeras capas de una red convolucional se activan ante la presencia de ciertos patrones vinculados a detalles muy pequeños.
#
# A medida que avanzamos en las distintas capas de una red neuronal convolucional, los filtros se van activando a medida que detectan patrones de formas cada vez mas complejos.
#
# Lo que propone este paper es asignarle a la activación de las primeras capas de una red neuronal convolucional (por ejemplo VGG19) la definición del estilo y a la activación de las últimas capas de la red neuronal convolucional, la definición del contenido.
#
# La idea de este paper es, a partir de dos imágenes (una que aporte el estilo y otra que aporte el contenido) analizar cómo es la activación de las primeras capas para la imagen que aporta el estilo y cómo es la activación de las últimas capas de la red convolucional para la imagen que aporta el contenido. A partir de esto se intentará sintetizar una imagen que active los filtros de las primeras capas que se activaron con la imagen que aporta el estilo y los filtros de las últimas capas que se activaron con la imagen que aporta el contenido.
#
# A este procedimiento se lo denomina neural style transfer.
#
# # En este trabajo se deberá leer el paper mencionado y en base a ello, entender la implementación que se muestra a continuación y contestar preguntas sobre la misma.
#
# # Una metodología posible es hacer una lectura rápida del paper (aunque esto signifique no entender algunos detalles del mismo) y luego ir analizando el código y respondiendo las preguntas. A medida que se planteen las preguntas, volviendo a leer secciones específicas del paper terminará de entender los detalles que pudieran haber quedado pendientes.
#
# Lo primero que haremos es cargar dos imágenes, una que aporte el estilo y otra que aporte el contenido. A tal fin utilizaremos imágenes disponibles en la web.

# %%
# Imagen para estilo
# !wget https://upload.wikimedia.org/wikipedia/commons/5/52/La_noche_estrellada1.jpg

# Imagen para contenido
# !wget https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Neckarfront_T%C3%BCbingen_Mai_2017.jpg/775px-Neckarfront_T%C3%BCbingen_Mai_2017.jpg

# Creamos el directorio para los archivos de salida
# !mkdir -p /home/jmlasserre/Documents/ITBA_Deep_Learning/TransferLearning/Trabajo-Final-CV/content/output
# Out:
# --2022-07-15 15:08:09--  https://upload.wikimedia.org/wikipedia/commons/5/52/La_noche_estrellada1.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 2620:0:861:ed1a::2:b, 208.80.154.240
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|2620:0:861:ed1a::2:b|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 223725 (218K) [image/jpeg]
# Saving to: ‘La_noche_estrellada1.jpg.1’
#
# La_noche_estrellada 100%[===================>] 218,48K   428KB/s    in 0,5s
#
# 2022-07-15 15:08:10 (428 KB/s) - ‘La_noche_estrellada1.jpg.1’ saved [223725/223725]
#
# --2022-07-15 15:08:10--  https://upload.wikimedia.org/wikipedia/commons/thumb/f/f4/Neckarfront_T%C3%BCbingen_Mai_2017.jpg/775px-Neckarfront_T%C3%BCbingen_Mai_2017.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 2620:0:861:ed1a::2:b, 208.80.154.240
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|2620:0:861:ed1a::2:b|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 153015 (149K) [image/jpeg]
# Saving to: ‘775px-Neckarfront_Tübingen_Mai_2017.jpg.1’
#
# 775px-Neckarfront_T 100%[===================>] 149,43K   333KB/s    in 0,4s
#
# 2022-07-15 15:08:11 (333 KB/s) - ‘775px-Neckarfront_Tübingen_Mai_2017.jpg.1’ saved [153015/153015]

# %%
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse

from keras.applications import vgg19
from keras import backend as K
from pathlib import Path

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

tf.device("gpu:0")
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# Definimos las imagenes que vamos a utilizar, y el directorio de salida

base_image_path = Path("ciudadNoche.jpg")
style_reference_image_path = Path("Mondrian.jpg")
result_prefix = Path("content/Aliens")
iterations = 400

# %% [markdown]
# # 1) En base a lo visto en el paper ¿Qué significan los parámetros definidos en la siguiente celda?
#
# Respuesta: Cada uno de esos parámetros son utilizados para ponderar o pesar los componentes de la función de pérdida o loss

# %%
total_variation_weight = 1e-6
style_weight = 1e-5
content_weight = 2.5e-6
Iteration = 500

# %%
# Definimos el tamaño de las imágenes a utilizar
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# %% [markdown]
# # 2) Explicar qué hace la siguiente celda. En especial las últimas dos líneas de la función antes del return. ¿Por qué?
#
# Ayuda: https://keras.io/applications/
#
# Respuesta: Crea una función para cargar las imagenes, hacerles resize, transformarlas en un numpy array, y convertirlas en tensores para que puedan ser procesados correctamente por la NN. Es decir, la función devuelve la representación de la imagen en un tensor. Porque la forma con el que procesan los datos en las NN

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %% [markdown]
# # 3) Habiendo comprendido lo que hace la celda anterior, explique de manera muy concisa qué hace la siguiente celda. ¿Qué relación tiene con la celda anterior?
#
# Respuesta: Transforma el tensor en imagen. La relación que tiene con la celda anterior es que es su proceso inverso. O sea, revierte el preprocesamiento de la función anterior. La función en la celda anterior transforma la imagen en tensor, esta función transforma el tensor en imagen.

# %%
def deprocess_image(x):
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
# K.variable convierte un numpy array en un tensor, para 
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))
# Out:
# WARNING:tensorflow:From /home/jmlasserre/anaconda3/envs/SanExpedito/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# %% [markdown]
# Aclaración:
#
# La siguiente celda sirve para procesar las tres imagenes (contenido, estilo y salida) en un solo batch.

# %%
# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')

# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Out:
# Model loaded.

# %% [markdown]
# # 4) En la siguientes celdas:
#
# - ¿Qué es la matriz de Gram?¿Para qué se usa?
#
# La matriz de Gram es el producto punto o producto escalar entre los vectores del mapeo de las features i y j en la misma capa de la CNN. Se usa para mapear las correlaciones encontradas en la matriz original de las features. La distancia media cuadrática entre las entradas de la matriz de Gram de la imagen original y la de la imagen creada se minimiza para generar una textura que concuerde con la imagen utilizada para ese fin. En resumen, se usa en la función de pérdida de estilo (style_loss) para que la imagen generada conserve el estilo de la imagen de referencia del estilo.
#
# - ¿Por qué se permutan las dimensiones de x?
#
# Es necesario permutar los filtros hacia la primera dimensión para que las matrices queden ordenadas para calcular la matriz de Gram.

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %% [markdown]
# # 5) Losses:
#
# Explicar qué mide cada una de las losses en las siguientes tres celdas.
#
# Rta:
#
# - style_loss: mide la distancia entre las matrices de Gram con el propósito de minimizarla para manter la referencia de estilo. Busca conservar las correlaciones similares dentro de las diferentes capas con el objetivo de mantener las texturas.
# - content_loss: se utiliza para medir la distancia entre la imagen generada y la imagen utilizada como contenido. Al minimizarla, la CNN debería tener un resultado en la imagen generada similar a la imagen de base de contenido.
# - total_variation_loss: trabaja sobre los pixeles la imagen generada por la combinación.  Se puede pensar como una regularización para intentar evitar una 'pixelización' excesiva de la imagen resultante.

# %%
def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def total_variation_loss(x):
    assert K.ndim(x) == 4
    a = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
    b = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Armamos la loss total
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                            combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :] 
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(feature_layers)) * sl
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)

# %% [markdown]
# # 6) Explique el propósito de las siguientes tres celdas. ¿Qué hace la función fmin_l_bfgs_b? ¿En qué se diferencia con la implementación del paper? ¿Se puede utilizar alguna alternativa?
#
# Respuesta: El propósito es llevar a cabo del proceso de descenso por gradiente procesando utlizando la función de pérdida y la función que calcula los gradientes en un solo paso. fmin_l_bfgs_b minimiza la pérdida de estilo de la imagen generada y por cada iteración .

# %%
def eval_loss_and_grads(x):
    x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %% [markdown]
# # 7) Ejecute la siguiente celda y observe las imágenes de salida en cada iteración.

# %%
evaluator = Evaluator()

# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    fname = result_prefix / ('output_at_iteration_%d.png' % i)
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 273569.2
# Image saved as content/Aliens/output_at_iteration_0.png
# Iteration 0 completed in 13s
# Start of iteration 1
# Current loss value: 141191.67
# Image saved as content/Aliens/output_at_iteration_1.png
# Iteration 1 completed in 9s
# Start of iteration 2
# Current loss value: 90357.12
# Image saved as content/Aliens/output_at_iteration_2.png
# Iteration 2 completed in 9s
# Start of iteration 3
# Current loss value: 69474.58
# Image saved as content/Aliens/output_at_iteration_3.png
# Iteration 3 completed in 9s
# Start of iteration 4
# Current loss value: 58783.062
# Image saved as content/Aliens/output_at_iteration_4.png
# Iteration 4 completed in 9s
# Start of iteration 5
# Current loss value: 52019.28
# Image saved as content/Aliens/output_at_iteration_5.png
# Iteration 5 completed in 9s
# Start of iteration 6
# Current loss value: 47393.824
# Image saved as content/Aliens/output_at_iteration_6.png
# Iteration 6 completed in 9s
# Start of iteration 7
# Current loss value: 43984.58
# Image saved as content/Aliens/output_at_iteration_7.png
# Iteration 7 completed in 9s
# Start of iteration 8
# Current loss value: 41361.555
# Image saved as content/Aliens/output_at_iteration_8.png
# Iteration 8 completed in 9s
# Start of iteration 9
# Current loss value: 39128.168
# Image saved as content/Aliens/output_at_iteration_9.png
# Iteration 9 completed in 9s
# Start of iteration 10
# Current loss value: 37324.94
# Image saved as content/Aliens/output_at_iteration_10.png
# Iteration 10 completed in 9s
# Start of iteration 11
# Current loss value: 35813.258
# Image saved as content/Aliens/output_at_iteration_11.png
# Iteration 11 completed in 9s
# Start of iteration 12
# Current loss value: 34568.254
# Image saved as content/Aliens/output_at_iteration_12.png
# Iteration 12 completed in 9s
# Start of iteration 13
# Current loss value: 33519.18
# Image saved as content/Aliens/output_at_iteration_13.png
# Iteration 13 completed in 9s
# Start of iteration 14
# Current loss value: 32597.73
# Image saved as content/Aliens/output_at_iteration_14.png
# Iteration 14 completed in 9s
# Start of iteration 15
# Current loss value: 31802.293
# Image saved as content/Aliens/output_at_iteration_15.png
# Iteration 15 completed in 9s
# Start of iteration 16
# Current loss value: 31098.688
# Image saved as content/Aliens/output_at_iteration_16.png
# Iteration 16 completed in 9s
# Start of iteration 17
# Current loss value: 30482.795
# Image saved as content/Aliens/output_at_iteration_17.png
# Iteration 17 completed in 9s
# Start of iteration 18
# Current loss value: 29912.578
# Image saved as content/Aliens/output_at_iteration_18.png
# Iteration 18 completed in 9s
# Start of iteration 19
# Current loss value: 29393.422
# Image saved as content/Aliens/output_at_iteration_19.png
# Iteration 19 completed in 9s
# Start of iteration 20
# Current loss value: 28916.44
# Image saved as content/Aliens/output_at_iteration_20.png
# Iteration 20 completed in 9s
# Start of iteration 21
# Current loss value: 28472.88
# Image saved as content/Aliens/output_at_iteration_21.png
# Iteration 21 completed in 9s
# Start of iteration 22
# Current loss value: 28052.887
# Image saved as content/Aliens/output_at_iteration_22.png
# Iteration 22 completed in 9s
# Start of iteration 23
# Current loss value: 27672.79
# Image saved as content/Aliens/output_at_iteration_23.png
# Iteration 23 completed in 9s
# Start of iteration 24
# Current loss value: 27335.727
# Image saved as content/Aliens/output_at_iteration_24.png
# Iteration 24 completed in 9s
# Start of iteration 25
# Current loss value: 27024.797
# Image saved as content/Aliens/output_at_iteration_25.png
# Iteration 25 completed in 9s
# Start of iteration 26
# Current loss value: 26745.102
# Image saved as content/Aliens/output_at_iteration_26.png
# Iteration 26 completed in 9s
# Start of iteration 27
# Current loss value: 26481.748
# Image saved as content/Aliens/output_at_iteration_27.png
# Iteration 27 completed in 9s
# Start of iteration 28
# Current loss value: 26235.36
# Image saved as content/Aliens/output_at_iteration_28.png
# Iteration 28 completed in 9s
# Start of iteration 29
# Current loss value: 26002.586
# Image saved as content/Aliens/output_at_iteration_29.png
# Iteration 29 completed in 9s
# Start of iteration 30
# Current loss value: 25777.072
# Image saved as content/Aliens/output_at_iteration_30.png
# Iteration 30 completed in 9s
# Start of iteration 31
# Current loss value: 25564.91
# Image saved as content/Aliens/output_at_iteration_31.png
# Iteration 31 completed in 9s
# Start of iteration 32
# Current loss value: 25368.445
# Image saved as content/Aliens/output_at_iteration_32.png
# Iteration 32 completed in 9s
# Start of iteration 33
# Current loss value: 25168.87
# Image saved as content/Aliens/output_at_iteration_33.png
# Iteration 33 completed in 9s
# Start of iteration 34
# Current loss value: 24985.469
# Image saved as content/Aliens/output_at_iteration_34.png
# Iteration 34 completed in 9s
# Start of iteration 35
# Current loss value: 24809.55
# Image saved as content/Aliens/output_at_iteration_35.png
# Iteration 35 completed in 9s
# Start of iteration 36
# Current loss value: 24641.895
# Image saved as content/Aliens/output_at_iteration_36.png
# Iteration 36 completed in 9s
# Start of iteration 37
# Current loss value: 24479.668
# Image saved as content/Aliens/output_at_iteration_37.png
# Iteration 37 completed in 9s
# Start of iteration 38
# Current loss value: 24310.764
# Image saved as content/Aliens/output_at_iteration_38.png
# Iteration 38 completed in 9s
# Start of iteration 39
# Current loss value: 24156.004
# Image saved as content/Aliens/output_at_iteration_39.png
# Iteration 39 completed in 9s
# Start of iteration 40
# Current loss value: 23995.19
# Image saved as content/Aliens/output_at_iteration_40.png
# Iteration 40 completed in 9s
# Start of iteration 41
# Current loss value: 23832.023
# Image saved as content/Aliens/output_at_iteration_41.png
# Iteration 41 completed in 9s
# Start of iteration 42
# Current loss value: 23672.29
# Image saved as content/Aliens/output_at_iteration_42.png
# Iteration 42 completed in 9s
# Start of iteration 43
# Current loss value: 23522.094
# Image saved as content/Aliens/output_at_iteration_43.png
# Iteration 43 completed in 9s
# Start of iteration 44
# Current loss value: 23372.79
# Image saved as content/Aliens/output_at_iteration_44.png
# Iteration 44 completed in 9s
# Start of iteration 45
# Current loss value: 23223.637
# Image saved as content/Aliens/output_at_iteration_45.png
# Iteration 45 completed in 9s
# Start of iteration 46
# Current loss value: 23082.436
# Image saved as content/Aliens/output_at_iteration_46.png
# Iteration 46 completed in 9s
# Start of iteration 47
# Current loss value: 22929.803
# Image saved as content/Aliens/output_at_iteration_47.png
# Iteration 47 completed in 9s
# Start of iteration 48
# Current loss value: 22790.482
# Image saved as content/Aliens/output_at_iteration_48.png
# Iteration 48 completed in 9s
# Start of iteration 49
# Current loss value: 22659.637
# Image saved as content/Aliens/output_at_iteration_49.png
# Iteration 49 completed in 9s
# Start of iteration 50
# Current loss value: 22535.502
# Image saved as content/Aliens/output_at_iteration_50.png
# Iteration 50 completed in 9s
# Start of iteration 51
# Current loss value: 22416.12
# Image saved as content/Aliens/output_at_iteration_51.png
# Iteration 51 completed in 9s
# Start of iteration 52
# Current loss value: 22301.51
# Image saved as content/Aliens/output_at_iteration_52.png
# Iteration 52 completed in 9s
# Start of iteration 53
# Current loss value: 22190.688
# Image saved as content/Aliens/output_at_iteration_53.png
# Iteration 53 completed in 9s
# Start of iteration 54
# Current loss value: 22085.084
# Image saved as content/Aliens/output_at_iteration_54.png
# Iteration 54 completed in 9s
# Start of iteration 55
# Current loss value: 21980.518
# Image saved as content/Aliens/output_at_iteration_55.png
# Iteration 55 completed in 9s
# Start of iteration 56
# Current loss value: 21877.842
# Image saved as content/Aliens/output_at_iteration_56.png
# Iteration 56 completed in 9s
# Start of iteration 57
# Current loss value: 21776.666
# Image saved as content/Aliens/output_at_iteration_57.png
# Iteration 57 completed in 9s
# Start of iteration 58
# Current loss value: 21682.338
# Image saved as content/Aliens/output_at_iteration_58.png
# Iteration 58 completed in 9s
# Start of iteration 59
# Current loss value: 21588.44
# Image saved as content/Aliens/output_at_iteration_59.png
# Iteration 59 completed in 9s
# Start of iteration 60
# Current loss value: 21495.904
# Image saved as content/Aliens/output_at_iteration_60.png
# Iteration 60 completed in 9s
# Start of iteration 61
# Current loss value: 21400.412
# Image saved as content/Aliens/output_at_iteration_61.png
# Iteration 61 completed in 9s
# Start of iteration 62
# Current loss value: 21305.879
# Image saved as content/Aliens/output_at_iteration_62.png
# Iteration 62 completed in 9s
# Start of iteration 63
# Current loss value: 21209.629
# Image saved as content/Aliens/output_at_iteration_63.png
# Iteration 63 completed in 9s
# Start of iteration 64
# Current loss value: 21112.045
# Image saved as content/Aliens/output_at_iteration_64.png
# Iteration 64 completed in 9s
# Start of iteration 65
# Current loss value: 21016.398
# Image saved as content/Aliens/output_at_iteration_65.png
# Iteration 65 completed in 9s
# Start of iteration 66
# Current loss value: 20920.219
# Image saved as content/Aliens/output_at_iteration_66.png
# Iteration 66 completed in 9s
# Start of iteration 67
# Current loss value: 20838.047
# Image saved as content/Aliens/output_at_iteration_67.png
# Iteration 67 completed in 9s
# Start of iteration 68
# Current loss value: 20761.094
# Image saved as content/Aliens/output_at_iteration_68.png
# Iteration 68 completed in 9s
# Start of iteration 69
# Current loss value: 20685.87
# Image saved as content/Aliens/output_at_iteration_69.png
# Iteration 69 completed in 9s
# Start of iteration 70
# Current loss value: 20611.123
# Image saved as content/Aliens/output_at_iteration_70.png
# Iteration 70 completed in 9s
# Start of iteration 71
# Current loss value: 20536.055
# Image saved as content/Aliens/output_at_iteration_71.png
# Iteration 71 completed in 9s
# Start of iteration 72
# Current loss value: 20465.436
# Image saved as content/Aliens/output_at_iteration_72.png
# Iteration 72 completed in 9s
# Start of iteration 73
# Current loss value: 20393.8
# Image saved as content/Aliens/output_at_iteration_73.png
# Iteration 73 completed in 9s
# Start of iteration 74
# Current loss value: 20330.037
# Image saved as content/Aliens/output_at_iteration_74.png
# Iteration 74 completed in 9s
# Start of iteration 75
# Current loss value: 20271.082
# Image saved as content/Aliens/output_at_iteration_75.png
# Iteration 75 completed in 9s
# Start of iteration 76
# Current loss value: 20213.414
# Image saved as content/Aliens/output_at_iteration_76.png
# Iteration 76 completed in 9s
# Start of iteration 77
# Current loss value: 20158.27
# Image saved as content/Aliens/output_at_iteration_77.png
# Iteration 77 completed in 9s
# Start of iteration 78
# Current loss value: 20103.863
# Image saved as content/Aliens/output_at_iteration_78.png
# Iteration 78 completed in 9s
# Start of iteration 79
# Current loss value: 20051.84
# Image saved as content/Aliens/output_at_iteration_79.png
# Iteration 79 completed in 9s
# Start of iteration 80
# Current loss value: 20000.662
# Image saved as content/Aliens/output_at_iteration_80.png
# Iteration 80 completed in 9s
# Start of iteration 81
# Current loss value: 19949.92
# Image saved as content/Aliens/output_at_iteration_81.png
# Iteration 81 completed in 9s
# Start of iteration 82
# Current loss value: 19900.166
# Image saved as content/Aliens/output_at_iteration_82.png
# Iteration 82 completed in 9s
# Start of iteration 83
# Current loss value: 19850.195
# Image saved as content/Aliens/output_at_iteration_83.png
# Iteration 83 completed in 9s
# Start of iteration 84
# Current loss value: 19800.953
# Image saved as content/Aliens/output_at_iteration_84.png
# Iteration 84 completed in 9s
# Start of iteration 85
# Current loss value: 19752.627
# Image saved as content/Aliens/output_at_iteration_85.png
# Iteration 85 completed in 9s
# Start of iteration 86
# Current loss value: 19704.418
# Image saved as content/Aliens/output_at_iteration_86.png
# Iteration 86 completed in 9s
# Start of iteration 87
# Current loss value: 19655.705
# Image saved as content/Aliens/output_at_iteration_87.png
# Iteration 87 completed in 9s
# Start of iteration 88
# Current loss value: 19607.32
# Image saved as content/Aliens/output_at_iteration_88.png
# Iteration 88 completed in 9s
# Start of iteration 89
# Current loss value: 19559.361
# Image saved as content/Aliens/output_at_iteration_89.png
# Iteration 89 completed in 9s
# Start of iteration 90
# Current loss value: 19514.562
# Image saved as content/Aliens/output_at_iteration_90.png
# Iteration 90 completed in 9s
# Start of iteration 91
# Current loss value: 19472.035
# Image saved as content/Aliens/output_at_iteration_91.png
# Iteration 91 completed in 9s
# Start of iteration 92
# Current loss value: 19430.898
# Image saved as content/Aliens/output_at_iteration_92.png
# Iteration 92 completed in 9s
# Start of iteration 93
# Current loss value: 19391.078
# Image saved as content/Aliens/output_at_iteration_93.png
# Iteration 93 completed in 9s
# Start of iteration 94
# Current loss value: 19352.395
# Image saved as content/Aliens/output_at_iteration_94.png
# Iteration 94 completed in 9s
# Start of iteration 95
# Current loss value: 19315.035
# Image saved as content/Aliens/output_at_iteration_95.png
# Iteration 95 completed in 9s
# Start of iteration 96
# Current loss value: 19279.21
# Image saved as content/Aliens/output_at_iteration_96.png
# Iteration 96 completed in 9s
# Start of iteration 97
# Current loss value: 19244.691
# Image saved as content/Aliens/output_at_iteration_97.png
# Iteration 97 completed in 9s
# Start of iteration 98
# Current loss value: 19210.602
# Image saved as content/Aliens/output_at_iteration_98.png
# Iteration 98 completed in 9s
# Start of iteration 99
# Current loss value: 19177.639
# Image saved as content/Aliens/output_at_iteration_99.png
# Iteration 99 completed in 9s
# Start of iteration 100
# Current loss value: 19145.652
# Image saved as content/Aliens/output_at_iteration_100.png
# Iteration 100 completed in 9s
# Start of iteration 101
# Current loss value: 19114.637
# Image saved as content/Aliens/output_at_iteration_101.png
# Iteration 101 completed in 9s
# Start of iteration 102
# Current loss value: 19084.084
# Image saved as content/Aliens/output_at_iteration_102.png
# Iteration 102 completed in 9s
# Start of iteration 103
# Current loss value: 19054.238
# Image saved as content/Aliens/output_at_iteration_103.png
# Iteration 103 completed in 9s
# Start of iteration 104
# Current loss value: 19024.324
# Image saved as content/Aliens/output_at_iteration_104.png
# Iteration 104 completed in 9s
# Start of iteration 105
# Current loss value: 18995.512
# Image saved as content/Aliens/output_at_iteration_105.png
# Iteration 105 completed in 9s
# Start of iteration 106
# Current loss value: 18967.672
# Image saved as content/Aliens/output_at_iteration_106.png
# Iteration 106 completed in 9s
# Start of iteration 107
# Current loss value: 18940.436
# Image saved as content/Aliens/output_at_iteration_107.png
# Iteration 107 completed in 9s
# Start of iteration 108
# Current loss value: 18913.432
# Image saved as content/Aliens/output_at_iteration_108.png
# Iteration 108 completed in 9s
# Start of iteration 109
# Current loss value: 18887.627
# Image saved as content/Aliens/output_at_iteration_109.png
# Iteration 109 completed in 9s
# Start of iteration 110
# Current loss value: 18862.148
# Image saved as content/Aliens/output_at_iteration_110.png
# Iteration 110 completed in 9s
# Start of iteration 111
# Current loss value: 18837.012
# Image saved as content/Aliens/output_at_iteration_111.png
# Iteration 111 completed in 9s
# Start of iteration 112
# Current loss value: 18812.23
# Image saved as content/Aliens/output_at_iteration_112.png
# Iteration 112 completed in 9s
# Start of iteration 113
# Current loss value: 18787.662
# Image saved as content/Aliens/output_at_iteration_113.png
# Iteration 113 completed in 9s
# Start of iteration 114
# Current loss value: 18763.562
# Image saved as content/Aliens/output_at_iteration_114.png
# Iteration 114 completed in 9s
# Start of iteration 115
# Current loss value: 18740.025
# Image saved as content/Aliens/output_at_iteration_115.png
# Iteration 115 completed in 9s
# Start of iteration 116
# Current loss value: 18716.7
# Image saved as content/Aliens/output_at_iteration_116.png
# Iteration 116 completed in 9s
# Start of iteration 117
# Current loss value: 18693.568
# Image saved as content/Aliens/output_at_iteration_117.png
# Iteration 117 completed in 9s
# Start of iteration 118
# Current loss value: 18671.031
# Image saved as content/Aliens/output_at_iteration_118.png
# Iteration 118 completed in 9s
# Start of iteration 119
# Current loss value: 18648.787
# Image saved as content/Aliens/output_at_iteration_119.png
# Iteration 119 completed in 9s
# Start of iteration 120
# Current loss value: 18626.8
# Image saved as content/Aliens/output_at_iteration_120.png
# Iteration 120 completed in 9s
# Start of iteration 121
# Current loss value: 18604.623
# Image saved as content/Aliens/output_at_iteration_121.png
# Iteration 121 completed in 9s
# Start of iteration 122
# Current loss value: 18582.66
# Image saved as content/Aliens/output_at_iteration_122.png
# Iteration 122 completed in 9s
# Start of iteration 123
# Current loss value: 18561.271
# Image saved as content/Aliens/output_at_iteration_123.png
# Iteration 123 completed in 9s
# Start of iteration 124
# Current loss value: 18539.566
# Image saved as content/Aliens/output_at_iteration_124.png
# Iteration 124 completed in 9s
# Start of iteration 125
# Current loss value: 18517.91
# Image saved as content/Aliens/output_at_iteration_125.png
# Iteration 125 completed in 9s
# Start of iteration 126
# Current loss value: 18496.664
# Image saved as content/Aliens/output_at_iteration_126.png
# Iteration 126 completed in 9s
# Start of iteration 127
# Current loss value: 18475.334
# Image saved as content/Aliens/output_at_iteration_127.png
# Iteration 127 completed in 9s
# Start of iteration 128
# Current loss value: 18454.355
# Image saved as content/Aliens/output_at_iteration_128.png
# Iteration 128 completed in 9s
# Start of iteration 129
# Current loss value: 18433.059
# Image saved as content/Aliens/output_at_iteration_129.png
# Iteration 129 completed in 9s
# Start of iteration 130
# Current loss value: 18411.758
# Image saved as content/Aliens/output_at_iteration_130.png
# Iteration 130 completed in 9s
# Start of iteration 131
# Current loss value: 18390.328
# Image saved as content/Aliens/output_at_iteration_131.png
# Iteration 131 completed in 9s
# Start of iteration 132
# Current loss value: 18368.969
# Image saved as content/Aliens/output_at_iteration_132.png
# Iteration 132 completed in 9s
# Start of iteration 133
# Current loss value: 18346.479
# Image saved as content/Aliens/output_at_iteration_133.png
# Iteration 133 completed in 9s
# Start of iteration 134
# Current loss value: 18323.379
# Image saved as content/Aliens/output_at_iteration_134.png
# Iteration 134 completed in 9s
# Start of iteration 135
# Current loss value: 18298.643
# Image saved as content/Aliens/output_at_iteration_135.png
# Iteration 135 completed in 9s
# Start of iteration 136
# Current loss value: 18270.361
# Image saved as content/Aliens/output_at_iteration_136.png
# Iteration 136 completed in 9s
# Start of iteration 137
# Current loss value: 18232.678
# Image saved as content/Aliens/output_at_iteration_137.png
# Iteration 137 completed in 9s
# Start of iteration 138
# Current loss value: 18199.143
# Image saved as content/Aliens/output_at_iteration_138.png
# Iteration 138 completed in 9s
# Start of iteration 139
# Current loss value: 18174.742
# Image saved as content/Aliens/output_at_iteration_139.png
# Iteration 139 completed in 9s
# Start of iteration 140
# Current loss value: 18150.158
# Image saved as content/Aliens/output_at_iteration_140.png
# Iteration 140 completed in 9s
# Start of iteration 141
# Current loss value: 18128.314
# Image saved as content/Aliens/output_at_iteration_141.png
# Iteration 141 completed in 9s
# Start of iteration 142
# Current loss value: 18106.273
# Image saved as content/Aliens/output_at_iteration_142.png
# Iteration 142 completed in 9s
# Start of iteration 143
# Current loss value: 18085.902
# Image saved as content/Aliens/output_at_iteration_143.png
# Iteration 143 completed in 9s
# Start of iteration 144
# Current loss value: 18065.328
# Image saved as content/Aliens/output_at_iteration_144.png
# Iteration 144 completed in 9s
# Start of iteration 145
# Current loss value: 18045.55
# Image saved as content/Aliens/output_at_iteration_145.png
# Iteration 145 completed in 9s
# Start of iteration 146
# Current loss value: 18026.02
# Image saved as content/Aliens/output_at_iteration_146.png
# Iteration 146 completed in 9s
# Start of iteration 147
# Current loss value: 18007.416
# Image saved as content/Aliens/output_at_iteration_147.png
# Iteration 147 completed in 9s
# Start of iteration 148
# Current loss value: 17988.668
# Image saved as content/Aliens/output_at_iteration_148.png
# Iteration 148 completed in 9s
# Start of iteration 149
# Current loss value: 17970.459
# Image saved as content/Aliens/output_at_iteration_149.png
# Iteration 149 completed in 9s
# Start of iteration 150
# Current loss value: 17952.91
# Image saved as content/Aliens/output_at_iteration_150.png
# Iteration 150 completed in 9s
# Start of iteration 151
# Current loss value: 17934.863
# Image saved as content/Aliens/output_at_iteration_151.png
# Iteration 151 completed in 9s
# Start of iteration 152
# Current loss value: 17917.387
# Image saved as content/Aliens/output_at_iteration_152.png
# Iteration 152 completed in 9s
# Start of iteration 153
# Current loss value: 17899.844
# Image saved as content/Aliens/output_at_iteration_153.png
# Iteration 153 completed in 9s
# Start of iteration 154
# Current loss value: 17882.568
# Image saved as content/Aliens/output_at_iteration_154.png
# Iteration 154 completed in 9s
# Start of iteration 155
# Current loss value: 17865.2
# Image saved as content/Aliens/output_at_iteration_155.png
# Iteration 155 completed in 9s
# Start of iteration 156
# Current loss value: 17848.16
# Image saved as content/Aliens/output_at_iteration_156.png
# Iteration 156 completed in 9s
# Start of iteration 157
# Current loss value: 17831.176
# Image saved as content/Aliens/output_at_iteration_157.png
# Iteration 157 completed in 9s
# Start of iteration 158
# Current loss value: 17814.588
# Image saved as content/Aliens/output_at_iteration_158.png
# Iteration 158 completed in 9s
# Start of iteration 159
# Current loss value: 17797.96
# Image saved as content/Aliens/output_at_iteration_159.png
# Iteration 159 completed in 9s
# Start of iteration 160
# Current loss value: 17781.742
# Image saved as content/Aliens/output_at_iteration_160.png
# Iteration 160 completed in 9s
# Start of iteration 161
# Current loss value: 17765.148
# Image saved as content/Aliens/output_at_iteration_161.png
# Iteration 161 completed in 9s
# Start of iteration 162
# Current loss value: 17748.965
# Image saved as content/Aliens/output_at_iteration_162.png
# Iteration 162 completed in 9s
# Start of iteration 163
# Current loss value: 17732.564
# Image saved as content/Aliens/output_at_iteration_163.png
# Iteration 163 completed in 9s
# Start of iteration 164
# Current loss value: 17715.998
# Image saved as content/Aliens/output_at_iteration_164.png
# Iteration 164 completed in 9s
# Start of iteration 165
# Current loss value: 17699.375
# Image saved as content/Aliens/output_at_iteration_165.png
# Iteration 165 completed in 9s
# Start of iteration 166
# Current loss value: 17683.355
# Image saved as content/Aliens/output_at_iteration_166.png
# Iteration 166 completed in 9s
# Start of iteration 167
# Current loss value: 17667.336
# Image saved as content/Aliens/output_at_iteration_167.png
# Iteration 167 completed in 9s
# Start of iteration 168
# Current loss value: 17651.66
# Image saved as content/Aliens/output_at_iteration_168.png
# Iteration 168 completed in 9s
# Start of iteration 169
# Current loss value: 17635.852
# Image saved as content/Aliens/output_at_iteration_169.png
# Iteration 169 completed in 9s
# Start of iteration 170
# Current loss value: 17620.145
# Image saved as content/Aliens/output_at_iteration_170.png
# Iteration 170 completed in 9s
# Start of iteration 171
# Current loss value: 17604.371
# Image saved as content/Aliens/output_at_iteration_171.png
# Iteration 171 completed in 9s
# Start of iteration 172
# Current loss value: 17588.184
# Image saved as content/Aliens/output_at_iteration_172.png
# Iteration 172 completed in 9s
# Start of iteration 173
# Current loss value: 17572.209
# Image saved as content/Aliens/output_at_iteration_173.png
# Iteration 173 completed in 9s
# Start of iteration 174
# Current loss value: 17556.258
# Image saved as content/Aliens/output_at_iteration_174.png
# Iteration 174 completed in 9s
# Start of iteration 175
# Current loss value: 17540.566
# Image saved as content/Aliens/output_at_iteration_175.png
# Iteration 175 completed in 9s
# Start of iteration 176
# Current loss value: 17524.678
# Image saved as content/Aliens/output_at_iteration_176.png
# Iteration 176 completed in 9s
# Start of iteration 177
# Current loss value: 17509.47
# Image saved as content/Aliens/output_at_iteration_177.png
# Iteration 177 completed in 9s
# Start of iteration 178
# Current loss value: 17494.434
# Image saved as content/Aliens/output_at_iteration_178.png
# Iteration 178 completed in 9s
# Start of iteration 179
# Current loss value: 17479.686
# Image saved as content/Aliens/output_at_iteration_179.png
# Iteration 179 completed in 9s
# Start of iteration 180
# Current loss value: 17464.676
# Image saved as content/Aliens/output_at_iteration_180.png
# Iteration 180 completed in 9s
# Start of iteration 181
# Current loss value: 17450.076
# Image saved as content/Aliens/output_at_iteration_181.png
# Iteration 181 completed in 9s
# Start of iteration 182
# Current loss value: 17435.703
# Image saved as content/Aliens/output_at_iteration_182.png
# Iteration 182 completed in 9s
# Start of iteration 183
# Current loss value: 17421.506
# Image saved as content/Aliens/output_at_iteration_183.png
# Iteration 183 completed in 9s
# Start of iteration 184
# Current loss value: 17407.61
# Image saved as content/Aliens/output_at_iteration_184.png
# Iteration 184 completed in 9s
# Start of iteration 185
# Current loss value: 17394.088
# Image saved as content/Aliens/output_at_iteration_185.png
# Iteration 185 completed in 9s
# Start of iteration 186
# Current loss value: 17381.033
# Image saved as content/Aliens/output_at_iteration_186.png
# Iteration 186 completed in 9s
# Start of iteration 187
# Current loss value: 17367.703
# Image saved as content/Aliens/output_at_iteration_187.png
# Iteration 187 completed in 9s
# Start of iteration 188
# Current loss value: 17354.447
# Image saved as content/Aliens/output_at_iteration_188.png
# Iteration 188 completed in 9s
# Start of iteration 189
# Current loss value: 17341.494
# Image saved as content/Aliens/output_at_iteration_189.png
# Iteration 189 completed in 9s
# Start of iteration 190
# Current loss value: 17328.855
# Image saved as content/Aliens/output_at_iteration_190.png
# Iteration 190 completed in 9s
# Start of iteration 191
# Current loss value: 17316.238
# Image saved as content/Aliens/output_at_iteration_191.png
# Iteration 191 completed in 9s
# Start of iteration 192
# Current loss value: 17303.604
# Image saved as content/Aliens/output_at_iteration_192.png
# Iteration 192 completed in 9s
# Start of iteration 193
# Current loss value: 17291.203
# Image saved as content/Aliens/output_at_iteration_193.png
# Iteration 193 completed in 9s
# Start of iteration 194
# Current loss value: 17278.879
# Image saved as content/Aliens/output_at_iteration_194.png
# Iteration 194 completed in 9s
# Start of iteration 195
# Current loss value: 17266.549
# Image saved as content/Aliens/output_at_iteration_195.png
# Iteration 195 completed in 9s
# Start of iteration 196
# Current loss value: 17254.018
# Image saved as content/Aliens/output_at_iteration_196.png
# Iteration 196 completed in 9s
# Start of iteration 197
# Current loss value: 17241.662
# Image saved as content/Aliens/output_at_iteration_197.png
# Iteration 197 completed in 9s
# Start of iteration 198
# Current loss value: 17229.49
# Image saved as content/Aliens/output_at_iteration_198.png
# Iteration 198 completed in 9s
# Start of iteration 199
# Current loss value: 17217.105
# Image saved as content/Aliens/output_at_iteration_199.png
# Iteration 199 completed in 9s
# Start of iteration 200
# Current loss value: 17204.967
# Image saved as content/Aliens/output_at_iteration_200.png
# Iteration 200 completed in 9s
# Start of iteration 201
# Current loss value: 17192.71
# Image saved as content/Aliens/output_at_iteration_201.png
# Iteration 201 completed in 9s
# Start of iteration 202
# Current loss value: 17180.639
# Image saved as content/Aliens/output_at_iteration_202.png
# Iteration 202 completed in 9s
# Start of iteration 203
# Current loss value: 17168.61
# Image saved as content/Aliens/output_at_iteration_203.png
# Iteration 203 completed in 9s
# Start of iteration 204
# Current loss value: 17156.527
# Image saved as content/Aliens/output_at_iteration_204.png
# Iteration 204 completed in 9s
# Start of iteration 205
# Current loss value: 17144.271
# Image saved as content/Aliens/output_at_iteration_205.png
# Iteration 205 completed in 9s
# Start of iteration 206
# Current loss value: 17131.854
# Image saved as content/Aliens/output_at_iteration_206.png
# Iteration 206 completed in 9s
# Start of iteration 207
# Current loss value: 17119.68
# Image saved as content/Aliens/output_at_iteration_207.png
# Iteration 207 completed in 9s
# Start of iteration 208
# Current loss value: 17107.477
# Image saved as content/Aliens/output_at_iteration_208.png
# Iteration 208 completed in 9s
# Start of iteration 209
# Current loss value: 17095.498
# Image saved as content/Aliens/output_at_iteration_209.png
# Iteration 209 completed in 9s
# Start of iteration 210
# Current loss value: 17083.57
# Image saved as content/Aliens/output_at_iteration_210.png
# Iteration 210 completed in 9s
# Start of iteration 211
# Current loss value: 17071.484
# Image saved as content/Aliens/output_at_iteration_211.png
# Iteration 211 completed in 9s
# Start of iteration 212
# Current loss value: 17059.348
# Image saved as content/Aliens/output_at_iteration_212.png
# Iteration 212 completed in 9s
# Start of iteration 213
# Current loss value: 17047.148
# Image saved as content/Aliens/output_at_iteration_213.png
# Iteration 213 completed in 9s
# Start of iteration 214
# Current loss value: 17034.8
# Image saved as content/Aliens/output_at_iteration_214.png
# Iteration 214 completed in 9s
# Start of iteration 215
# Current loss value: 17022.684
# Image saved as content/Aliens/output_at_iteration_215.png
# Iteration 215 completed in 9s
# Start of iteration 216
# Current loss value: 17010.717
# Image saved as content/Aliens/output_at_iteration_216.png
# Iteration 216 completed in 9s
# Start of iteration 217
# Current loss value: 16998.748
# Image saved as content/Aliens/output_at_iteration_217.png
# Iteration 217 completed in 9s
# Start of iteration 218
# Current loss value: 16987.23
# Image saved as content/Aliens/output_at_iteration_218.png
# Iteration 218 completed in 9s
# Start of iteration 219
# Current loss value: 16975.658
# Image saved as content/Aliens/output_at_iteration_219.png
# Iteration 219 completed in 9s
# Start of iteration 220
# Current loss value: 16964.447
# Image saved as content/Aliens/output_at_iteration_220.png
# Iteration 220 completed in 9s
# Start of iteration 221
# Current loss value: 16953.125
# Image saved as content/Aliens/output_at_iteration_221.png
# Iteration 221 completed in 9s
# Start of iteration 222
# Current loss value: 16941.89
# Image saved as content/Aliens/output_at_iteration_222.png
# Iteration 222 completed in 9s
# Start of iteration 223
# Current loss value: 16930.732
# Image saved as content/Aliens/output_at_iteration_223.png
# Iteration 223 completed in 9s
# Start of iteration 224
# Current loss value: 16919.82
# Image saved as content/Aliens/output_at_iteration_224.png
# Iteration 224 completed in 9s
# Start of iteration 225
# Current loss value: 16909.006
# Image saved as content/Aliens/output_at_iteration_225.png
# Iteration 225 completed in 9s
# Start of iteration 226
# Current loss value: 16898.271
# Image saved as content/Aliens/output_at_iteration_226.png
# Iteration 226 completed in 9s
# Start of iteration 227
# Current loss value: 16887.746
# Image saved as content/Aliens/output_at_iteration_227.png
# Iteration 227 completed in 9s
# Start of iteration 228
# Current loss value: 16877.46
# Image saved as content/Aliens/output_at_iteration_228.png
# Iteration 228 completed in 9s
# Start of iteration 229
# Current loss value: 16867.041
# Image saved as content/Aliens/output_at_iteration_229.png
# Iteration 229 completed in 9s
# Start of iteration 230
# Current loss value: 16856.83
# Image saved as content/Aliens/output_at_iteration_230.png
# Iteration 230 completed in 9s
# Start of iteration 231
# Current loss value: 16846.568
# Image saved as content/Aliens/output_at_iteration_231.png
# Iteration 231 completed in 9s
# Start of iteration 232
# Current loss value: 16836.332
# Image saved as content/Aliens/output_at_iteration_232.png
# Iteration 232 completed in 9s
# Start of iteration 233
# Current loss value: 16826.098
# Image saved as content/Aliens/output_at_iteration_233.png
# Iteration 233 completed in 9s
# Start of iteration 234
# Current loss value: 16815.916
# Image saved as content/Aliens/output_at_iteration_234.png
# Iteration 234 completed in 9s
# Start of iteration 235
# Current loss value: 16806.074
# Image saved as content/Aliens/output_at_iteration_235.png
# Iteration 235 completed in 9s
# Start of iteration 236
# Current loss value: 16796.232
# Image saved as content/Aliens/output_at_iteration_236.png
# Iteration 236 completed in 9s
# Start of iteration 237
# Current loss value: 16786.701
# Image saved as content/Aliens/output_at_iteration_237.png
# Iteration 237 completed in 9s
# Start of iteration 238
# Current loss value: 16777.09
# Image saved as content/Aliens/output_at_iteration_238.png
# Iteration 238 completed in 9s
# Start of iteration 239
# Current loss value: 16767.707
# Image saved as content/Aliens/output_at_iteration_239.png
# Iteration 239 completed in 9s
# Start of iteration 240
# Current loss value: 16758.225
# Image saved as content/Aliens/output_at_iteration_240.png
# Iteration 240 completed in 9s
# Start of iteration 241
# Current loss value: 16748.848
# Image saved as content/Aliens/output_at_iteration_241.png
# Iteration 241 completed in 9s
# Start of iteration 242
# Current loss value: 16739.475
# Image saved as content/Aliens/output_at_iteration_242.png
# Iteration 242 completed in 9s
# Start of iteration 243
# Current loss value: 16730.336
# Image saved as content/Aliens/output_at_iteration_243.png
# Iteration 243 completed in 9s
# Start of iteration 244
# Current loss value: 16721.066
# Image saved as content/Aliens/output_at_iteration_244.png
# Iteration 244 completed in 9s
# Start of iteration 245
# Current loss value: 16711.908
# Image saved as content/Aliens/output_at_iteration_245.png
# Iteration 245 completed in 9s
# Start of iteration 246
# Current loss value: 16702.754
# Image saved as content/Aliens/output_at_iteration_246.png
# Iteration 246 completed in 9s
# Start of iteration 247
# Current loss value: 16693.498
# Image saved as content/Aliens/output_at_iteration_247.png
# Iteration 247 completed in 9s
# Start of iteration 248
# Current loss value: 16684.316
# Image saved as content/Aliens/output_at_iteration_248.png
# Iteration 248 completed in 9s
# Start of iteration 249
# Current loss value: 16674.922
# Image saved as content/Aliens/output_at_iteration_249.png
# Iteration 249 completed in 9s
# Start of iteration 250
# Current loss value: 16665.764
# Image saved as content/Aliens/output_at_iteration_250.png
# Iteration 250 completed in 9s
# Start of iteration 251
# Current loss value: 16656.652
# Image saved as content/Aliens/output_at_iteration_251.png
# Iteration 251 completed in 9s
# Start of iteration 252
# Current loss value: 16647.96
# Image saved as content/Aliens/output_at_iteration_252.png
# Iteration 252 completed in 9s
# Start of iteration 253
# Current loss value: 16638.992
# Image saved as content/Aliens/output_at_iteration_253.png
# Iteration 253 completed in 9s
# Start of iteration 254
# Current loss value: 16630.178
# Image saved as content/Aliens/output_at_iteration_254.png
# Iteration 254 completed in 9s
# Start of iteration 255
# Current loss value: 16621.404
# Image saved as content/Aliens/output_at_iteration_255.png
# Iteration 255 completed in 9s
# Start of iteration 256
# Current loss value: 16612.75
# Image saved as content/Aliens/output_at_iteration_256.png
# Iteration 256 completed in 9s
# Start of iteration 257
# Current loss value: 16604.008
# Image saved as content/Aliens/output_at_iteration_257.png
# Iteration 257 completed in 9s
# Start of iteration 258
# Current loss value: 16595.271
# Image saved as content/Aliens/output_at_iteration_258.png
# Iteration 258 completed in 9s
# Start of iteration 259
# Current loss value: 16586.44
# Image saved as content/Aliens/output_at_iteration_259.png
# Iteration 259 completed in 9s
# Start of iteration 260
# Current loss value: 16577.68
# Image saved as content/Aliens/output_at_iteration_260.png
# Iteration 260 completed in 9s
# Start of iteration 261
# Current loss value: 16569.002
# Image saved as content/Aliens/output_at_iteration_261.png
# Iteration 261 completed in 9s
# Start of iteration 262
# Current loss value: 16560.258
# Image saved as content/Aliens/output_at_iteration_262.png
# Iteration 262 completed in 9s
# Start of iteration 263
# Current loss value: 16551.562
# Image saved as content/Aliens/output_at_iteration_263.png
# Iteration 263 completed in 9s
# Start of iteration 264
# Current loss value: 16542.514
# Image saved as content/Aliens/output_at_iteration_264.png
# Iteration 264 completed in 9s
# Start of iteration 265
# Current loss value: 16533.428
# Image saved as content/Aliens/output_at_iteration_265.png
# Iteration 265 completed in 9s
# Start of iteration 266
# Current loss value: 16524.139
# Image saved as content/Aliens/output_at_iteration_266.png
# Iteration 266 completed in 9s
# Start of iteration 267
# Current loss value: 16514.842
# Image saved as content/Aliens/output_at_iteration_267.png
# Iteration 267 completed in 9s
# Start of iteration 268
# Current loss value: 16505.305
# Image saved as content/Aliens/output_at_iteration_268.png
# Iteration 268 completed in 9s
# Start of iteration 269
# Current loss value: 16495.89
# Image saved as content/Aliens/output_at_iteration_269.png
# Iteration 269 completed in 9s
# Start of iteration 270
# Current loss value: 16486.168
# Image saved as content/Aliens/output_at_iteration_270.png
# Iteration 270 completed in 9s
# Start of iteration 271
# Current loss value: 16476.748
# Image saved as content/Aliens/output_at_iteration_271.png
# Iteration 271 completed in 9s
# Start of iteration 272
# Current loss value: 16467.611
# Image saved as content/Aliens/output_at_iteration_272.png
# Iteration 272 completed in 9s
# Start of iteration 273
# Current loss value: 16459.133
# Image saved as content/Aliens/output_at_iteration_273.png
# Iteration 273 completed in 9s
# Start of iteration 274
# Current loss value: 16450.832
# Image saved as content/Aliens/output_at_iteration_274.png
# Iteration 274 completed in 9s
# Start of iteration 275
# Current loss value: 16442.994
# Image saved as content/Aliens/output_at_iteration_275.png
# Iteration 275 completed in 9s
# Start of iteration 276
# Current loss value: 16435.121
# Image saved as content/Aliens/output_at_iteration_276.png
# Iteration 276 completed in 9s
# Start of iteration 277
# Current loss value: 16427.516
# Image saved as content/Aliens/output_at_iteration_277.png
# Iteration 277 completed in 9s
# Start of iteration 278
# Current loss value: 16419.928
# Image saved as content/Aliens/output_at_iteration_278.png
# Iteration 278 completed in 9s
# Start of iteration 279
# Current loss value: 16412.766
# Image saved as content/Aliens/output_at_iteration_279.png
# Iteration 279 completed in 9s
# Start of iteration 280
# Current loss value: 16405.492
# Image saved as content/Aliens/output_at_iteration_280.png
# Iteration 280 completed in 9s
# Start of iteration 281
# Current loss value: 16398.348
# Image saved as content/Aliens/output_at_iteration_281.png
# Iteration 281 completed in 9s
# Start of iteration 282
# Current loss value: 16391.348
# Image saved as content/Aliens/output_at_iteration_282.png
# Iteration 282 completed in 9s
# Start of iteration 283
# Current loss value: 16384.406
# Image saved as content/Aliens/output_at_iteration_283.png
# Iteration 283 completed in 9s
# Start of iteration 284
# Current loss value: 16377.638
# Image saved as content/Aliens/output_at_iteration_284.png
# Iteration 284 completed in 9s
# Start of iteration 285
# Current loss value: 16371.048
# Image saved as content/Aliens/output_at_iteration_285.png
# Iteration 285 completed in 9s
# Start of iteration 286
# Current loss value: 16364.408
# Image saved as content/Aliens/output_at_iteration_286.png
# Iteration 286 completed in 9s
# Start of iteration 287
# Current loss value: 16357.8125
# Image saved as content/Aliens/output_at_iteration_287.png
# Iteration 287 completed in 9s
# Start of iteration 288
# Current loss value: 16351.262
# Image saved as content/Aliens/output_at_iteration_288.png
# Iteration 288 completed in 9s
# Start of iteration 289
# Current loss value: 16344.705
# Image saved as content/Aliens/output_at_iteration_289.png
# Iteration 289 completed in 9s
# Start of iteration 290
# Current loss value: 16338.204
# Image saved as content/Aliens/output_at_iteration_290.png
# Iteration 290 completed in 9s
# Start of iteration 291
# Current loss value: 16331.912
# Image saved as content/Aliens/output_at_iteration_291.png
# Iteration 291 completed in 9s
# Start of iteration 292
# Current loss value: 16325.607
# Image saved as content/Aliens/output_at_iteration_292.png
# Iteration 292 completed in 9s
# Start of iteration 293
# Current loss value: 16319.329
# Image saved as content/Aliens/output_at_iteration_293.png
# Iteration 293 completed in 9s
# Start of iteration 294
# Current loss value: 16312.946
# Image saved as content/Aliens/output_at_iteration_294.png
# Iteration 294 completed in 9s
# Start of iteration 295
# Current loss value: 16306.575
# Image saved as content/Aliens/output_at_iteration_295.png
# Iteration 295 completed in 9s
# Start of iteration 296
# Current loss value: 16300.076
# Image saved as content/Aliens/output_at_iteration_296.png
# Iteration 296 completed in 9s
# Start of iteration 297
# Current loss value: 16293.635
# Image saved as content/Aliens/output_at_iteration_297.png
# Iteration 297 completed in 9s
# Start of iteration 298
# Current loss value: 16287.142
# Image saved as content/Aliens/output_at_iteration_298.png
# Iteration 298 completed in 9s
# Start of iteration 299
# Current loss value: 16280.788
# Image saved as content/Aliens/output_at_iteration_299.png
# Iteration 299 completed in 9s
# Start of iteration 300
# Current loss value: 16274.184
# Image saved as content/Aliens/output_at_iteration_300.png
# Iteration 300 completed in 9s
# Start of iteration 301
# Current loss value: 16267.484
# Image saved as content/Aliens/output_at_iteration_301.png
# Iteration 301 completed in 9s
# Start of iteration 302
# Current loss value: 16260.796
# Image saved as content/Aliens/output_at_iteration_302.png
# Iteration 302 completed in 9s
# Start of iteration 303
# Current loss value: 16254.163
# Image saved as content/Aliens/output_at_iteration_303.png
# Iteration 303 completed in 9s
# Start of iteration 304
# Current loss value: 16247.467
# Image saved as content/Aliens/output_at_iteration_304.png
# Iteration 304 completed in 9s
# Start of iteration 305
# Current loss value: 16240.966
# Image saved as content/Aliens/output_at_iteration_305.png
# Iteration 305 completed in 9s
# Start of iteration 306
# Current loss value: 16234.446
# Image saved as content/Aliens/output_at_iteration_306.png
# Iteration 306 completed in 9s
# Start of iteration 307
# Current loss value: 16228.062
# Image saved as content/Aliens/output_at_iteration_307.png
# Iteration 307 completed in 9s
# Start of iteration 308
# Current loss value: 16221.533
# Image saved as content/Aliens/output_at_iteration_308.png
# Iteration 308 completed in 9s
# Start of iteration 309
# Current loss value: 16215.254
# Image saved as content/Aliens/output_at_iteration_309.png
# Iteration 309 completed in 9s
# Start of iteration 310
# Current loss value: 16209.102
# Image saved as content/Aliens/output_at_iteration_310.png
# Iteration 310 completed in 9s
# Start of iteration 311
# Current loss value: 16203.121
# Image saved as content/Aliens/output_at_iteration_311.png
# Iteration 311 completed in 9s
# Start of iteration 312
# Current loss value: 16197.309
# Image saved as content/Aliens/output_at_iteration_312.png
# Iteration 312 completed in 9s
# Start of iteration 313
# Current loss value: 16191.464
# Image saved as content/Aliens/output_at_iteration_313.png
# Iteration 313 completed in 9s
# Start of iteration 314
# Current loss value: 16185.735
# Image saved as content/Aliens/output_at_iteration_314.png
# Iteration 314 completed in 9s
# Start of iteration 315
# Current loss value: 16179.879
# Image saved as content/Aliens/output_at_iteration_315.png
# Iteration 315 completed in 9s
# Start of iteration 316
# Current loss value: 16173.961
# Image saved as content/Aliens/output_at_iteration_316.png
# Iteration 316 completed in 9s
# Start of iteration 317
# Current loss value: 16168.17
# Image saved as content/Aliens/output_at_iteration_317.png
# Iteration 317 completed in 9s
# Start of iteration 318
# Current loss value: 16162.288
# Image saved as content/Aliens/output_at_iteration_318.png
# Iteration 318 completed in 9s
# Start of iteration 319
# Current loss value: 16156.49
# Image saved as content/Aliens/output_at_iteration_319.png
# Iteration 319 completed in 9s
# Start of iteration 320
# Current loss value: 16150.762
# Image saved as content/Aliens/output_at_iteration_320.png
# Iteration 320 completed in 9s
# Start of iteration 321
# Current loss value: 16145.334
# Image saved as content/Aliens/output_at_iteration_321.png
# Iteration 321 completed in 9s
# Start of iteration 322
# Current loss value: 16139.724
# Image saved as content/Aliens/output_at_iteration_322.png
# Iteration 322 completed in 9s
# Start of iteration 323
# Current loss value: 16134.367
# Image saved as content/Aliens/output_at_iteration_323.png
# Iteration 323 completed in 9s
# Start of iteration 324
# Current loss value: 16128.877
# Image saved as content/Aliens/output_at_iteration_324.png
# Iteration 324 completed in 9s
# Start of iteration 325
# Current loss value: 16123.664
# Image saved as content/Aliens/output_at_iteration_325.png
# Iteration 325 completed in 9s
# Start of iteration 326
# Current loss value: 16118.4
# Image saved as content/Aliens/output_at_iteration_326.png
# Iteration 326 completed in 9s
# Start of iteration 327
# Current loss value: 16113.37
# Image saved as content/Aliens/output_at_iteration_327.png
# Iteration 327 completed in 9s
# Start of iteration 328
# Current loss value: 16108.338
# Image saved as content/Aliens/output_at_iteration_328.png
# Iteration 328 completed in 9s
# Start of iteration 329
# Current loss value: 16103.439
# Image saved as content/Aliens/output_at_iteration_329.png
# Iteration 329 completed in 9s
# Start of iteration 330
# Current loss value: 16098.469
# Image saved as content/Aliens/output_at_iteration_330.png
# Iteration 330 completed in 9s
# Start of iteration 331
# Current loss value: 16093.717
# Image saved as content/Aliens/output_at_iteration_331.png
# Iteration 331 completed in 9s
# Start of iteration 332
# Current loss value: 16088.916
# Image saved as content/Aliens/output_at_iteration_332.png
# Iteration 332 completed in 9s
# Start of iteration 333
# Current loss value: 16084.281
# Image saved as content/Aliens/output_at_iteration_333.png
# Iteration 333 completed in 9s
# Start of iteration 334
# Current loss value: 16079.576
# Image saved as content/Aliens/output_at_iteration_334.png
# Iteration 334 completed in 9s
# Start of iteration 335
# Current loss value: 16075.088
# Image saved as content/Aliens/output_at_iteration_335.png
# Iteration 335 completed in 9s
# Start of iteration 336
# Current loss value: 16070.513
# Image saved as content/Aliens/output_at_iteration_336.png
# Iteration 336 completed in 9s
# Start of iteration 337
# Current loss value: 16066.103
# Image saved as content/Aliens/output_at_iteration_337.png
# Iteration 337 completed in 9s
# Start of iteration 338
# Current loss value: 16061.521
# Image saved as content/Aliens/output_at_iteration_338.png
# Iteration 338 completed in 9s
# Start of iteration 339
# Current loss value: 16057.234
# Image saved as content/Aliens/output_at_iteration_339.png
# Iteration 339 completed in 9s
# Start of iteration 340
# Current loss value: 16052.759
# Image saved as content/Aliens/output_at_iteration_340.png
# Iteration 340 completed in 9s
# Start of iteration 341
# Current loss value: 16048.522
# Image saved as content/Aliens/output_at_iteration_341.png
# Iteration 341 completed in 9s
# Start of iteration 342
# Current loss value: 16044.191
# Image saved as content/Aliens/output_at_iteration_342.png
# Iteration 342 completed in 9s
# Start of iteration 343
# Current loss value: 16040.015
# Image saved as content/Aliens/output_at_iteration_343.png
# Iteration 343 completed in 9s
# Start of iteration 344
# Current loss value: 16035.799
# Image saved as content/Aliens/output_at_iteration_344.png
# Iteration 344 completed in 9s
# Start of iteration 345
# Current loss value: 16031.61
# Image saved as content/Aliens/output_at_iteration_345.png
# Iteration 345 completed in 9s
# Start of iteration 346
# Current loss value: 16027.503
# Image saved as content/Aliens/output_at_iteration_346.png
# Iteration 346 completed in 9s
# Start of iteration 347
# Current loss value: 16023.43
# Image saved as content/Aliens/output_at_iteration_347.png
# Iteration 347 completed in 9s
# Start of iteration 348
# Current loss value: 16019.388
# Image saved as content/Aliens/output_at_iteration_348.png
# Iteration 348 completed in 9s
# Start of iteration 349
# Current loss value: 16015.323
# Image saved as content/Aliens/output_at_iteration_349.png
# Iteration 349 completed in 9s
# Start of iteration 350
# Current loss value: 16011.347
# Image saved as content/Aliens/output_at_iteration_350.png
# Iteration 350 completed in 9s
# Start of iteration 351
# Current loss value: 16007.365
# Image saved as content/Aliens/output_at_iteration_351.png
# Iteration 351 completed in 9s
# Start of iteration 352
# Current loss value: 16003.476
# Image saved as content/Aliens/output_at_iteration_352.png
# Iteration 352 completed in 9s
# Start of iteration 353
# Current loss value: 15999.604
# Image saved as content/Aliens/output_at_iteration_353.png
# Iteration 353 completed in 9s
# Start of iteration 354
# Current loss value: 15995.794
# Image saved as content/Aliens/output_at_iteration_354.png
# Iteration 354 completed in 9s
# Start of iteration 355
# Current loss value: 15991.938
# Image saved as content/Aliens/output_at_iteration_355.png
# Iteration 355 completed in 9s
# Start of iteration 356
# Current loss value: 15988.153
# Image saved as content/Aliens/output_at_iteration_356.png
# Iteration 356 completed in 9s
# Start of iteration 357
# Current loss value: 15984.366
# Image saved as content/Aliens/output_at_iteration_357.png
# Iteration 357 completed in 9s
# Start of iteration 358
# Current loss value: 15980.635
# Image saved as content/Aliens/output_at_iteration_358.png
# Iteration 358 completed in 9s
# Start of iteration 359
# Current loss value: 15976.863
# Image saved as content/Aliens/output_at_iteration_359.png
# Iteration 359 completed in 9s
# Start of iteration 360
# Current loss value: 15973.197
# Image saved as content/Aliens/output_at_iteration_360.png
# Iteration 360 completed in 9s
# Start of iteration 361
# Current loss value: 15969.5625
# Image saved as content/Aliens/output_at_iteration_361.png
# Iteration 361 completed in 9s
# Start of iteration 362
# Current loss value: 15965.961
# Image saved as content/Aliens/output_at_iteration_362.png
# Iteration 362 completed in 9s
# Start of iteration 363
# Current loss value: 15962.368
# Image saved as content/Aliens/output_at_iteration_363.png
# Iteration 363 completed in 9s
# Start of iteration 364
# Current loss value: 15958.83
# Image saved as content/Aliens/output_at_iteration_364.png
# Iteration 364 completed in 9s
# Start of iteration 365
# Current loss value: 15955.341
# Image saved as content/Aliens/output_at_iteration_365.png
# Iteration 365 completed in 9s
# Start of iteration 366
# Current loss value: 15951.793
# Image saved as content/Aliens/output_at_iteration_366.png
# Iteration 366 completed in 9s
# Start of iteration 367
# Current loss value: 15948.293
# Image saved as content/Aliens/output_at_iteration_367.png
# Iteration 367 completed in 9s
# Start of iteration 368
# Current loss value: 15944.658
# Image saved as content/Aliens/output_at_iteration_368.png
# Iteration 368 completed in 9s
# Start of iteration 369
# Current loss value: 15941.05
# Image saved as content/Aliens/output_at_iteration_369.png
# Iteration 369 completed in 9s
# Start of iteration 370
# Current loss value: 15937.339
# Image saved as content/Aliens/output_at_iteration_370.png
# Iteration 370 completed in 9s
# Start of iteration 371
# Current loss value: 15933.84
# Image saved as content/Aliens/output_at_iteration_371.png
# Iteration 371 completed in 9s
# Start of iteration 372
# Current loss value: 15930.287
# Image saved as content/Aliens/output_at_iteration_372.png
# Iteration 372 completed in 9s
# Start of iteration 373
# Current loss value: 15926.798
# Image saved as content/Aliens/output_at_iteration_373.png
# Iteration 373 completed in 9s
# Start of iteration 374
# Current loss value: 15923.188
# Image saved as content/Aliens/output_at_iteration_374.png
# Iteration 374 completed in 9s
# Start of iteration 375
# Current loss value: 15919.764
# Image saved as content/Aliens/output_at_iteration_375.png
# Iteration 375 completed in 9s
# Start of iteration 376
# Current loss value: 15916.293
# Image saved as content/Aliens/output_at_iteration_376.png
# Iteration 376 completed in 9s
# Start of iteration 377
# Current loss value: 15912.889
# Image saved as content/Aliens/output_at_iteration_377.png
# Iteration 377 completed in 9s
# Start of iteration 378
# Current loss value: 15909.434
# Image saved as content/Aliens/output_at_iteration_378.png
# Iteration 378 completed in 9s
# Start of iteration 379
# Current loss value: 15906.007
# Image saved as content/Aliens/output_at_iteration_379.png
# Iteration 379 completed in 9s
# Start of iteration 380
# Current loss value: 15902.511
# Image saved as content/Aliens/output_at_iteration_380.png
# Iteration 380 completed in 9s
# Start of iteration 381
# Current loss value: 15899.119
# Image saved as content/Aliens/output_at_iteration_381.png
# Iteration 381 completed in 9s
# Start of iteration 382
# Current loss value: 15895.659
# Image saved as content/Aliens/output_at_iteration_382.png
# Iteration 382 completed in 9s
# Start of iteration 383
# Current loss value: 15892.289
# Image saved as content/Aliens/output_at_iteration_383.png
# Iteration 383 completed in 9s
# Start of iteration 384
# Current loss value: 15888.827
# Image saved as content/Aliens/output_at_iteration_384.png
# Iteration 384 completed in 9s
# Start of iteration 385
# Current loss value: 15885.358
# Image saved as content/Aliens/output_at_iteration_385.png
# Iteration 385 completed in 9s
# Start of iteration 386
# Current loss value: 15881.828
# Image saved as content/Aliens/output_at_iteration_386.png
# Iteration 386 completed in 9s
# Start of iteration 387
# Current loss value: 15878.324
# Image saved as content/Aliens/output_at_iteration_387.png
# Iteration 387 completed in 9s
# Start of iteration 388
# Current loss value: 15874.785
# Image saved as content/Aliens/output_at_iteration_388.png
# Iteration 388 completed in 9s
# Start of iteration 389
# Current loss value: 15871.3125
# Image saved as content/Aliens/output_at_iteration_389.png
# Iteration 389 completed in 9s
# Start of iteration 390
# Current loss value: 15867.878
# Image saved as content/Aliens/output_at_iteration_390.png
# Iteration 390 completed in 9s
# Start of iteration 391
# Current loss value: 15864.441
# Image saved as content/Aliens/output_at_iteration_391.png
# Iteration 391 completed in 9s
# Start of iteration 392
# Current loss value: 15861.073
# Image saved as content/Aliens/output_at_iteration_392.png
# Iteration 392 completed in 9s
# Start of iteration 393
# Current loss value: 15857.701
# Image saved as content/Aliens/output_at_iteration_393.png
# Iteration 393 completed in 9s
# Start of iteration 394
# Current loss value: 15854.403
# Image saved as content/Aliens/output_at_iteration_394.png
# Iteration 394 completed in 9s
# Start of iteration 395
# Current loss value: 15851.152
# Image saved as content/Aliens/output_at_iteration_395.png
# Iteration 395 completed in 9s
# Start of iteration 396
# Current loss value: 15847.982
# Image saved as content/Aliens/output_at_iteration_396.png
# Iteration 396 completed in 9s
# Start of iteration 397
# Current loss value: 15844.771
# Image saved as content/Aliens/output_at_iteration_397.png
# Iteration 397 completed in 9s
# Start of iteration 398
# Current loss value: 15841.657
# Image saved as content/Aliens/output_at_iteration_398.png
# Iteration 398 completed in 9s
# Start of iteration 399
# Current loss value: 15838.468
# Image saved as content/Aliens/output_at_iteration_399.png
# Iteration 399 completed in 9s

# %% [markdown]
# # 8) Generar imágenes para distintas combinaciones de pesos de las losses. Explicar las diferencias. (Adjuntar las imágenes generadas como archivos separados.)
#
# Respuesta:
#
# # 9) Cambiar las imágenes de contenido y estilo por unas elegidas por usted. Adjuntar el resultado.
#
# Respuesta:
