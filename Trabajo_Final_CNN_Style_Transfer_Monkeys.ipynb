# %% [markdown]
# # Style Transfer
#
# <img src="https://i0.wp.com/chelseatroy.com/wp-content/uploads/2018/12/neural_style_transfer.png?resize=768%2C311&ssl=1">
#
# La idea de este trabajo final es reproducir el siguiente paper:
#
# https://arxiv.org/pdf/1508.06576.pdf
#
# El objetivo es transferir el estilo de una imagen dada a otra imagen distinta.
#
# Como hemos visto en clase, las primeras capas de una red convolucional se activan ante la presencia de ciertos patrones vinculados a detalles muy pequeños.
#
# A medida que avanzamos en las distintas capas de una red neuronal convolucional, los filtros se van activando a medida que detectan patrones de formas cada vez mas complejos.
#
# Lo que propone este paper es asignarle a la activación de las primeras capas de una red neuronal convolucional (por ejemplo VGG19) la definición del estilo y a la activación de las últimas capas de la red neuronal convolucional, la definición del contenido.
#
# La idea de este paper es, a partir de dos imágenes (una que aporte el estilo y otra que aporte el contenido) analizar cómo es la activación de las primeras capas para la imagen que aporta el estilo y cómo es la activación de las últimas capas de la red convolucional para la imagen que aporta el contenido. A partir de esto se intentará sintetizar una imagen que active los filtros de las primeras capas que se activaron con la imagen que aporta el estilo y los filtros de las últimas capas que se activaron con la imagen que aporta el contenido.
#
# A este procedimiento se lo denomina neural style transfer.
#
# # En este trabajo se deberá leer el paper mencionado y en base a ello, entender la implementación que se muestra a continuación y contestar preguntas sobre la misma.
#
# # Una metodología posible es hacer una lectura rápida del paper (aunque esto signifique no entender algunos detalles del mismo) y luego ir analizando el código y respondiendo las preguntas. A medida que se planteen las preguntas, volviendo a leer secciones específicas del paper terminará de entender los detalles que pudieran haber quedado pendientes.
#
# Lo primero que haremos es cargar dos imágenes, una que aporte el estilo y otra que aporte el contenido. A tal fin utilizaremos imágenes disponibles en la web.

# %%
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse

from keras.applications import vgg19
from keras import backend as K
from pathlib import Path

# %%
import tensorflow as tf
tf.compat.v1.disable_eager_execution()

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession

tf.device("gpu:0")
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
# Definimos las imagenes que vamos a utilizar, y el directorio de salida

base_image_path = Path("01Content-gorila.jpg")
style_reference_image_path = Path("02Style-henri-rousseau.jpg")
result_prefix = Path("content/Monkeys")
iterations = 400

# %% [markdown]
# # 1) En base a lo visto en el paper ¿Qué significan los parámetros definidos en la siguiente celda?
#
# Respuesta: Cada uno de esos parámetros son utilizados para ponderar o pesar los componentes de la función de pérdida o loss

# %%
total_variation_weight = 0
style_weight = 1
content_weight = 2.5e-6
Iteration = 500

# %%
# Definimos el tamaño de las imágenes a utilizar
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height)

# %% [markdown]
# # 2) Explicar qué hace la siguiente celda. En especial las últimas dos líneas de la función antes del return. ¿Por qué?
#
# Ayuda: https://keras.io/applications/
#
# Respuesta: Crea una función para cargar las imagenes, hacerles resize, transformarlas en un numpy array, y convertirlas en tensores para que puedan ser procesados correctamente por la NN. Es decir, la función devuelve la representación de la imagen en un tensor

# %%
def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %% [markdown]
# # 3) Habiendo comprendido lo que hace la celda anterior, explique de manera muy concisa qué hace la siguiente celda. ¿Qué relación tiene con la celda anterior?
#
# Respuesta: Transforma el tensor en imagen. La relación que tiene con la celda anterior es que es su proceso inverso. O sea, revierte el preprocesamiento de la función anterior. La función en la celda anterior transforma la imagen en tensor, esta función transforma el tensor en imagen.

# %%
def deprocess_image(x):
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
# K.variable convierte un numpy array en un tensor, para 
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))
# Out:
# WARNING:tensorflow:From /home/jmlasserre/anaconda3/envs/SanExpedito/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:1666: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# %% [markdown]
# Aclaración:
#
# La siguiente celda sirve para procesar las tres imagenes (contenido, estilo y salida) en un solo batch.

# %%
# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')

# get the symbolic outputs of each "key" layer (we gave them unique names).
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Out:
# Model loaded.

# %% [markdown]
# # 4) En la siguientes celdas:
#
# - ¿Qué es la matriz de Gram?¿Para qué se usa?
#
# La matriz de Gram es el producto punto o producto escalar entre los vectores del mapeo de las features i y j en la misma capa de la CNN. Se usa para mapear las correlaciones encontradas en la matriz original de las features. La distancia media cuadrática entre las entradas de la matriz de Gram de la imagen original y la de la imagen creada se minimiza para generar una textura que concuerde con la imagen utilizada para ese fin. En resumen, se usa en la función de pérdida de estilo (style_loss) para que la imagen generada conserve el estilo de la imagen de referencia del estilo.
#
# - ¿Por qué se permutan las dimensiones de x?
#
# Es necesario permutar los filtros hacia la primera dimensión para que las matrices queden ordenadas para calcular la matriz de Gram.

# %%
def gram_matrix(x):
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %% [markdown]
# # 5) Losses:
#
# Explicar qué mide cada una de las losses en las siguientes tres celdas.
#
# Rta:
#
# - style_loss: mide la distancia entre las matrices de Gram con el propósito de minimizarla para manter la referencia de estilo
# - content_loss: se utiliza para medir la distancia entre la imagen generada y la imagen utilizada como contenido. Al minimizarla, la CNN debería tener un resultado en la imagen generada similar a la imagen de base de contenido.
# - total_variation_loss: trabaja sobre los pixeles la imagen generada por la combinación.  Se puede pensar como una regularización para intentar evitar una 'pixelización' excesiva de la imagen resultante.

# %%
def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
def total_variation_loss(x):
    assert K.ndim(x) == 4
    a = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
    b = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# Armamos la loss total
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                            combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :] 
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(feature_layers)) * sl
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)

# %% [markdown]
# # 6) Explique el propósito de las siguientes tres celdas. ¿Qué hace la función fmin_l_bfgs_b? ¿En qué se diferencia con la implementación del paper? ¿Se puede utilizar alguna alternativa?
#
# Respuesta:

# %%
def eval_loss_and_grads(x):
    x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.

# %%
class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %% [markdown]
# # 7) Ejecute la siguiente celda y observe las imágenes de salida en cada iteración.

# %%
evaluator = Evaluator()

# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

for i in range(iterations):
    print('Start of iteration', i)
    start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    # save current generated image
    img = deprocess_image(x.copy())
    fname = result_prefix / ('output_at_iteration_%d.png' % i)
    save_img(fname, img)
    end_time = time.time()
    print('Image saved as', fname)
    print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 1383502200.0
# Image saved as content/Monkeys/output_at_iteration_0.png
# Iteration 0 completed in 66s
# Start of iteration 1
# Current loss value: 546456450.0
# Image saved as content/Monkeys/output_at_iteration_1.png
# Iteration 1 completed in 65s
# Start of iteration 2
# Current loss value: 334223260.0
# Image saved as content/Monkeys/output_at_iteration_2.png
# Iteration 2 completed in 66s
# Start of iteration 3
# Current loss value: 226524240.0
# Image saved as content/Monkeys/output_at_iteration_3.png
# Iteration 3 completed in 66s
# Start of iteration 4
# Current loss value: 165929310.0
# Image saved as content/Monkeys/output_at_iteration_4.png
# Iteration 4 completed in 66s
# Start of iteration 5
# Current loss value: 138113730.0
# Image saved as content/Monkeys/output_at_iteration_5.png
# Iteration 5 completed in 65s
# Start of iteration 6
# Current loss value: 110719200.0
# Image saved as content/Monkeys/output_at_iteration_6.png
# Iteration 6 completed in 65s
# Start of iteration 7
# Current loss value: 92841120.0
# Image saved as content/Monkeys/output_at_iteration_7.png
# Iteration 7 completed in 65s
# Start of iteration 8
# Current loss value: 82569510.0
# Image saved as content/Monkeys/output_at_iteration_8.png
# Iteration 8 completed in 65s
# Start of iteration 9
# Current loss value: 74006380.0
# Image saved as content/Monkeys/output_at_iteration_9.png
# Iteration 9 completed in 65s
# Start of iteration 10
# Current loss value: 68155180.0
# Image saved as content/Monkeys/output_at_iteration_10.png
# Iteration 10 completed in 65s
# Start of iteration 11
# Current loss value: 62259170.0
# Image saved as content/Monkeys/output_at_iteration_11.png
# Iteration 11 completed in 65s
# Start of iteration 12
# Current loss value: 56812424.0
# Image saved as content/Monkeys/output_at_iteration_12.png
# Iteration 12 completed in 65s
# Start of iteration 13
# Current loss value: 53019960.0
# Image saved as content/Monkeys/output_at_iteration_13.png
# Iteration 13 completed in 65s
# Start of iteration 14
# Current loss value: 50024230.0
# Image saved as content/Monkeys/output_at_iteration_14.png
# Iteration 14 completed in 66s
# Start of iteration 15
# Current loss value: 47447424.0
# Image saved as content/Monkeys/output_at_iteration_15.png
# Iteration 15 completed in 66s
# Start of iteration 16
# Current loss value: 44975150.0
# Image saved as content/Monkeys/output_at_iteration_16.png
# Iteration 16 completed in 65s
# Start of iteration 17
# Current loss value: 43008770.0
# Image saved as content/Monkeys/output_at_iteration_17.png
# Iteration 17 completed in 65s
# Start of iteration 18
# Current loss value: 41384330.0
# Image saved as content/Monkeys/output_at_iteration_18.png
# Iteration 18 completed in 65s
# Start of iteration 19
# Current loss value: 39724290.0
# Image saved as content/Monkeys/output_at_iteration_19.png
# Iteration 19 completed in 65s
# Start of iteration 20
# Current loss value: 37854520.0
# Image saved as content/Monkeys/output_at_iteration_20.png
# Iteration 20 completed in 65s
# Start of iteration 21
# Current loss value: 36218320.0
# Image saved as content/Monkeys/output_at_iteration_21.png
# Iteration 21 completed in 65s
# Start of iteration 22
# Current loss value: 34618188.0
# Image saved as content/Monkeys/output_at_iteration_22.png
# Iteration 22 completed in 65s
# Start of iteration 23
# Current loss value: 33312208.0
# Image saved as content/Monkeys/output_at_iteration_23.png
# Iteration 23 completed in 65s
# Start of iteration 24
# Current loss value: 32233248.0
# Image saved as content/Monkeys/output_at_iteration_24.png
# Iteration 24 completed in 65s
# Start of iteration 25
# Current loss value: 31180194.0
# Image saved as content/Monkeys/output_at_iteration_25.png
# Iteration 25 completed in 65s
# Start of iteration 26
# Current loss value: 30100104.0
# Image saved as content/Monkeys/output_at_iteration_26.png
# Iteration 26 completed in 65s
# Start of iteration 27
# Current loss value: 29233764.0
# Image saved as content/Monkeys/output_at_iteration_27.png
# Iteration 27 completed in 65s
# Start of iteration 28
# Current loss value: 28535770.0
# Image saved as content/Monkeys/output_at_iteration_28.png
# Iteration 28 completed in 65s
# Start of iteration 29
# Current loss value: 27229600.0
# Image saved as content/Monkeys/output_at_iteration_29.png
# Iteration 29 completed in 65s
# Start of iteration 30
# Current loss value: 26160352.0
# Image saved as content/Monkeys/output_at_iteration_30.png
# Iteration 30 completed in 66s
# Start of iteration 31
# Current loss value: 25446104.0
# Image saved as content/Monkeys/output_at_iteration_31.png
# Iteration 31 completed in 66s
# Start of iteration 32
# Current loss value: 24854872.0
# Image saved as content/Monkeys/output_at_iteration_32.png
# Iteration 32 completed in 65s
# Start of iteration 33
# Current loss value: 24326326.0
# Image saved as content/Monkeys/output_at_iteration_33.png
# Iteration 33 completed in 65s
# Start of iteration 34
# Current loss value: 23769946.0
# Image saved as content/Monkeys/output_at_iteration_34.png
# Iteration 34 completed in 65s
# Start of iteration 35
# Current loss value: 23257402.0
# Image saved as content/Monkeys/output_at_iteration_35.png
# Iteration 35 completed in 65s
# Start of iteration 36
# Current loss value: 22705898.0
# Image saved as content/Monkeys/output_at_iteration_36.png
# Iteration 36 completed in 65s
# Start of iteration 37
# Current loss value: 21902116.0
# Image saved as content/Monkeys/output_at_iteration_37.png
# Iteration 37 completed in 65s
# Start of iteration 38
# Current loss value: 21183344.0
# Image saved as content/Monkeys/output_at_iteration_38.png
# Iteration 38 completed in 65s
# Start of iteration 39
# Current loss value: 20459660.0
# Image saved as content/Monkeys/output_at_iteration_39.png
# Iteration 39 completed in 65s
# Start of iteration 40
# Current loss value: 19584346.0
# Image saved as content/Monkeys/output_at_iteration_40.png
# Iteration 40 completed in 65s
# Start of iteration 41
# Current loss value: 19132616.0
# Image saved as content/Monkeys/output_at_iteration_41.png
# Iteration 41 completed in 65s
# Start of iteration 42
# Current loss value: 18754746.0
# Image saved as content/Monkeys/output_at_iteration_42.png
# Iteration 42 completed in 65s
# Start of iteration 43
# Current loss value: 18519108.0
# Image saved as content/Monkeys/output_at_iteration_43.png
# Iteration 43 completed in 65s
# Start of iteration 44
# Current loss value: 18203798.0
# Image saved as content/Monkeys/output_at_iteration_44.png
# Iteration 44 completed in 65s
# Start of iteration 45
# Current loss value: 17941618.0
# Image saved as content/Monkeys/output_at_iteration_45.png
# Iteration 45 completed in 65s
# Start of iteration 46
# Current loss value: 17753642.0
# Image saved as content/Monkeys/output_at_iteration_46.png
# Iteration 46 completed in 65s
# Start of iteration 47
# Current loss value: 17545512.0
# Image saved as content/Monkeys/output_at_iteration_47.png
# Iteration 47 completed in 65s
# Start of iteration 48
# Current loss value: 17326556.0
# Image saved as content/Monkeys/output_at_iteration_48.png
# Iteration 48 completed in 65s
# Start of iteration 49
# Current loss value: 17149986.0
# Image saved as content/Monkeys/output_at_iteration_49.png
# Iteration 49 completed in 65s
# Start of iteration 50
# Current loss value: 16982808.0
# Image saved as content/Monkeys/output_at_iteration_50.png
# Iteration 50 completed in 65s
# Start of iteration 51
# Current loss value: 16725675.0
# Image saved as content/Monkeys/output_at_iteration_51.png
# Iteration 51 completed in 65s
# Start of iteration 52
# Current loss value: 16440606.0
# Image saved as content/Monkeys/output_at_iteration_52.png
# Iteration 52 completed in 65s
# Start of iteration 53
# Current loss value: 16262995.0
# Image saved as content/Monkeys/output_at_iteration_53.png
# Iteration 53 completed in 65s
# Start of iteration 54
# Current loss value: 16124775.0
# Image saved as content/Monkeys/output_at_iteration_54.png
# Iteration 54 completed in 65s
# Start of iteration 55
# Current loss value: 15929506.0
# Image saved as content/Monkeys/output_at_iteration_55.png
# Iteration 55 completed in 66s
# Start of iteration 56
# Current loss value: 15770037.0
# Image saved as content/Monkeys/output_at_iteration_56.png
# Iteration 56 completed in 65s
# Start of iteration 57
# Current loss value: 15582625.0
# Image saved as content/Monkeys/output_at_iteration_57.png
# Iteration 57 completed in 65s
# Start of iteration 58
# Current loss value: 15387334.0
# Image saved as content/Monkeys/output_at_iteration_58.png
# Iteration 58 completed in 66s
# Start of iteration 59
# Current loss value: 15238450.0
# Image saved as content/Monkeys/output_at_iteration_59.png
# Iteration 59 completed in 66s
# Start of iteration 60
# Current loss value: 15075082.0
# Image saved as content/Monkeys/output_at_iteration_60.png
# Iteration 60 completed in 65s
# Start of iteration 61
# Current loss value: 14918403.0
# Image saved as content/Monkeys/output_at_iteration_61.png
# Iteration 61 completed in 65s
# Start of iteration 62
# Current loss value: 14789453.0
# Image saved as content/Monkeys/output_at_iteration_62.png
# Iteration 62 completed in 65s
# Start of iteration 63
# Current loss value: 14650533.0
# Image saved as content/Monkeys/output_at_iteration_63.png
# Iteration 63 completed in 65s
# Start of iteration 64
# Current loss value: 14531319.0
# Image saved as content/Monkeys/output_at_iteration_64.png
# Iteration 64 completed in 65s
# Start of iteration 65
# Current loss value: 14408506.0
# Image saved as content/Monkeys/output_at_iteration_65.png
# Iteration 65 completed in 65s
# Start of iteration 66
# Current loss value: 14277276.0
# Image saved as content/Monkeys/output_at_iteration_66.png
# Iteration 66 completed in 65s
# Start of iteration 67
# Current loss value: 14122884.0
# Image saved as content/Monkeys/output_at_iteration_67.png
# Iteration 67 completed in 65s
# Start of iteration 68
# Current loss value: 13991623.0
# Image saved as content/Monkeys/output_at_iteration_68.png
# Iteration 68 completed in 65s
# Start of iteration 69
# Current loss value: 13867838.0
# Image saved as content/Monkeys/output_at_iteration_69.png
# Iteration 69 completed in 65s
# Start of iteration 70
# Current loss value: 13720323.0
# Image saved as content/Monkeys/output_at_iteration_70.png
# Iteration 70 completed in 65s
# Start of iteration 71
# Current loss value: 13560212.0
# Image saved as content/Monkeys/output_at_iteration_71.png
# Iteration 71 completed in 65s
# Start of iteration 72
# Current loss value: 13399159.0
# Image saved as content/Monkeys/output_at_iteration_72.png
# Iteration 72 completed in 65s
# Start of iteration 73
# Current loss value: 13180848.0
# Image saved as content/Monkeys/output_at_iteration_73.png
# Iteration 73 completed in 65s
# Start of iteration 74
# Current loss value: 12992276.0
# Image saved as content/Monkeys/output_at_iteration_74.png
# Iteration 74 completed in 65s
# Start of iteration 75
# Current loss value: 12898566.0
# Image saved as content/Monkeys/output_at_iteration_75.png
# Iteration 75 completed in 65s
# Start of iteration 76
# Current loss value: 12800395.0
# Image saved as content/Monkeys/output_at_iteration_76.png
# Iteration 76 completed in 65s
# Start of iteration 77
# Current loss value: 12696201.0
# Image saved as content/Monkeys/output_at_iteration_77.png
# Iteration 77 completed in 65s
# Start of iteration 78
# Current loss value: 12614237.0
# Image saved as content/Monkeys/output_at_iteration_78.png
# Iteration 78 completed in 65s
# Start of iteration 79
# Current loss value: 12526631.0
# Image saved as content/Monkeys/output_at_iteration_79.png
# Iteration 79 completed in 65s
# Start of iteration 80
# Current loss value: 12448244.0
# Image saved as content/Monkeys/output_at_iteration_80.png
# Iteration 80 completed in 65s
# Start of iteration 81
# Current loss value: 12325103.0
# Image saved as content/Monkeys/output_at_iteration_81.png
# Iteration 81 completed in 66s
# Start of iteration 82
# Current loss value: 12209879.0
# Image saved as content/Monkeys/output_at_iteration_82.png
# Iteration 82 completed in 67s
# Start of iteration 83
# Current loss value: 12118015.0
# Image saved as content/Monkeys/output_at_iteration_83.png
# Iteration 83 completed in 67s
# Start of iteration 84
# Current loss value: 12021872.0
# Image saved as content/Monkeys/output_at_iteration_84.png
# Iteration 84 completed in 67s
# Start of iteration 85
# Current loss value: 11930195.0
# Image saved as content/Monkeys/output_at_iteration_85.png
# Iteration 85 completed in 68s
# Start of iteration 86
# Current loss value: 11824021.0
# Image saved as content/Monkeys/output_at_iteration_86.png
# Iteration 86 completed in 67s
# Start of iteration 87
# Current loss value: 11739871.0
# Image saved as content/Monkeys/output_at_iteration_87.png
# Iteration 87 completed in 68s
# Start of iteration 88
# Current loss value: 11671482.0
# Image saved as content/Monkeys/output_at_iteration_88.png
# Iteration 88 completed in 68s
# Start of iteration 89
# Current loss value: 11568540.0
# Image saved as content/Monkeys/output_at_iteration_89.png
# Iteration 89 completed in 67s
# Start of iteration 90
# Current loss value: 11438989.0
# Image saved as content/Monkeys/output_at_iteration_90.png
# Iteration 90 completed in 67s
# Start of iteration 91
# Current loss value: 11347696.0
# Image saved as content/Monkeys/output_at_iteration_91.png
# Iteration 91 completed in 67s
# Start of iteration 92
# Current loss value: 11251869.0
# Image saved as content/Monkeys/output_at_iteration_92.png
# Iteration 92 completed in 67s
# Start of iteration 93
# Current loss value: 11179951.0
# Image saved as content/Monkeys/output_at_iteration_93.png
# Iteration 93 completed in 66s
# Start of iteration 94
# Current loss value: 11112841.0
# Image saved as content/Monkeys/output_at_iteration_94.png
# Iteration 94 completed in 66s
# Start of iteration 95
# Current loss value: 11043016.0
# Image saved as content/Monkeys/output_at_iteration_95.png
# Iteration 95 completed in 67s
# Start of iteration 96
# Current loss value: 10972522.0
# Image saved as content/Monkeys/output_at_iteration_96.png
# Iteration 96 completed in 66s
# Start of iteration 97
# Current loss value: 10876107.0
# Image saved as content/Monkeys/output_at_iteration_97.png
# Iteration 97 completed in 66s
# Start of iteration 98
# Current loss value: 10797450.0
# Image saved as content/Monkeys/output_at_iteration_98.png
# Iteration 98 completed in 66s
# Start of iteration 99
# Current loss value: 10656077.0
# Image saved as content/Monkeys/output_at_iteration_99.png
# Iteration 99 completed in 67s
# Start of iteration 100
# Current loss value: 10541512.0
# Image saved as content/Monkeys/output_at_iteration_100.png
# Iteration 100 completed in 67s
# Start of iteration 101
# Current loss value: 10484245.0
# Image saved as content/Monkeys/output_at_iteration_101.png
# Iteration 101 completed in 67s
# Start of iteration 102
# Current loss value: 10433900.0
# Image saved as content/Monkeys/output_at_iteration_102.png
# Iteration 102 completed in 66s
# Start of iteration 103
# Current loss value: 10363840.0
# Image saved as content/Monkeys/output_at_iteration_103.png
# Iteration 103 completed in 66s
# Start of iteration 104
# Current loss value: 10300062.0
# Image saved as content/Monkeys/output_at_iteration_104.png
# Iteration 104 completed in 66s
# Start of iteration 105
# Current loss value: 10237458.0
# Image saved as content/Monkeys/output_at_iteration_105.png
# Iteration 105 completed in 67s
# Start of iteration 106
# Current loss value: 10172247.0
# Image saved as content/Monkeys/output_at_iteration_106.png
# Iteration 106 completed in 67s
# Start of iteration 107
# Current loss value: 10103648.0
# Image saved as content/Monkeys/output_at_iteration_107.png
# Iteration 107 completed in 66s
# Start of iteration 108
# Current loss value: 10041104.0
# Image saved as content/Monkeys/output_at_iteration_108.png
# Iteration 108 completed in 66s
# Start of iteration 109
# Current loss value: 9991183.0
# Image saved as content/Monkeys/output_at_iteration_109.png
# Iteration 109 completed in 66s
# Start of iteration 110
# Current loss value: 9935570.0
# Image saved as content/Monkeys/output_at_iteration_110.png
# Iteration 110 completed in 66s
# Start of iteration 111
# Current loss value: 9890719.0
# Image saved as content/Monkeys/output_at_iteration_111.png
# Iteration 111 completed in 66s
# Start of iteration 112
# Current loss value: 9830918.0
# Image saved as content/Monkeys/output_at_iteration_112.png
# Iteration 112 completed in 66s
# Start of iteration 113
# Current loss value: 9787732.0
# Image saved as content/Monkeys/output_at_iteration_113.png
# Iteration 113 completed in 66s
# Start of iteration 114
# Current loss value: 9744413.0
# Image saved as content/Monkeys/output_at_iteration_114.png
# Iteration 114 completed in 66s
# Start of iteration 115
# Current loss value: 9698598.0
# Image saved as content/Monkeys/output_at_iteration_115.png
# Iteration 115 completed in 66s
# Start of iteration 116
# Current loss value: 9652649.0
# Image saved as content/Monkeys/output_at_iteration_116.png
# Iteration 116 completed in 66s
# Start of iteration 117
# Current loss value: 9605314.0
# Image saved as content/Monkeys/output_at_iteration_117.png
# Iteration 117 completed in 66s
# Start of iteration 118
# Current loss value: 9544721.0
# Image saved as content/Monkeys/output_at_iteration_118.png
# Iteration 118 completed in 66s
# Start of iteration 119
# Current loss value: 9502048.0
# Image saved as content/Monkeys/output_at_iteration_119.png
# Iteration 119 completed in 66s
# Start of iteration 120
# Current loss value: 9465189.0
# Image saved as content/Monkeys/output_at_iteration_120.png
# Iteration 120 completed in 66s
# Start of iteration 121
# Current loss value: 9428745.0
# Image saved as content/Monkeys/output_at_iteration_121.png
# Iteration 121 completed in 66s
# Start of iteration 122
# Current loss value: 9393112.0
# Image saved as content/Monkeys/output_at_iteration_122.png
# Iteration 122 completed in 66s
# Start of iteration 123
# Current loss value: 9354013.0
# Image saved as content/Monkeys/output_at_iteration_123.png
# Iteration 123 completed in 66s
# Start of iteration 124
# Current loss value: 9319827.0
# Image saved as content/Monkeys/output_at_iteration_124.png
# Iteration 124 completed in 66s
# Start of iteration 125
# Current loss value: 9282978.0
# Image saved as content/Monkeys/output_at_iteration_125.png
# Iteration 125 completed in 66s
# Start of iteration 126
# Current loss value: 9243172.0
# Image saved as content/Monkeys/output_at_iteration_126.png
# Iteration 126 completed in 66s
# Start of iteration 127
# Current loss value: 9211343.0
# Image saved as content/Monkeys/output_at_iteration_127.png
# Iteration 127 completed in 65s
# Start of iteration 128
# Current loss value: 9168563.0
# Image saved as content/Monkeys/output_at_iteration_128.png
# Iteration 128 completed in 66s
# Start of iteration 129
# Current loss value: 9127108.0
# Image saved as content/Monkeys/output_at_iteration_129.png
# Iteration 129 completed in 66s
# Start of iteration 130
# Current loss value: 9047581.0
# Image saved as content/Monkeys/output_at_iteration_130.png
# Iteration 130 completed in 66s
# Start of iteration 131
# Current loss value: 8976751.0
# Image saved as content/Monkeys/output_at_iteration_131.png
# Iteration 131 completed in 67s
# Start of iteration 132
# Current loss value: 8926959.0
# Image saved as content/Monkeys/output_at_iteration_132.png
# Iteration 132 completed in 66s
# Start of iteration 133
# Current loss value: 8881972.0
# Image saved as content/Monkeys/output_at_iteration_133.png
# Iteration 133 completed in 66s
# Start of iteration 134
# Current loss value: 8830982.0
# Image saved as content/Monkeys/output_at_iteration_134.png
# Iteration 134 completed in 66s
# Start of iteration 135
# Current loss value: 8778989.0
# Image saved as content/Monkeys/output_at_iteration_135.png
# Iteration 135 completed in 66s
# Start of iteration 136
# Current loss value: 8737841.0
# Image saved as content/Monkeys/output_at_iteration_136.png
# Iteration 136 completed in 66s
# Start of iteration 137
# Current loss value: 8701490.0
# Image saved as content/Monkeys/output_at_iteration_137.png
# Iteration 137 completed in 66s
# Start of iteration 138
# Current loss value: 8662307.0
# Image saved as content/Monkeys/output_at_iteration_138.png
# Iteration 138 completed in 66s
# Start of iteration 139
# Current loss value: 8619961.0
# Image saved as content/Monkeys/output_at_iteration_139.png
# Iteration 139 completed in 66s
# Start of iteration 140
# Current loss value: 8578139.0
# Image saved as content/Monkeys/output_at_iteration_140.png
# Iteration 140 completed in 66s
# Start of iteration 141
# Current loss value: 8541724.0
# Image saved as content/Monkeys/output_at_iteration_141.png
# Iteration 141 completed in 66s
# Start of iteration 142
# Current loss value: 8499242.0
# Image saved as content/Monkeys/output_at_iteration_142.png
# Iteration 142 completed in 66s
# Start of iteration 143
# Current loss value: 8462803.0
# Image saved as content/Monkeys/output_at_iteration_143.png
# Iteration 143 completed in 66s
# Start of iteration 144
# Current loss value: 8427903.0
# Image saved as content/Monkeys/output_at_iteration_144.png
# Iteration 144 completed in 66s
# Start of iteration 145
# Current loss value: 8395140.0
# Image saved as content/Monkeys/output_at_iteration_145.png
# Iteration 145 completed in 66s
# Start of iteration 146
# Current loss value: 8356565.0
# Image saved as content/Monkeys/output_at_iteration_146.png
# Iteration 146 completed in 66s
# Start of iteration 147
# Current loss value: 8320613.5
# Image saved as content/Monkeys/output_at_iteration_147.png
# Iteration 147 completed in 66s
# Start of iteration 148
# Current loss value: 8287396.5
# Image saved as content/Monkeys/output_at_iteration_148.png
# Iteration 148 completed in 66s
# Start of iteration 149
# Current loss value: 8257338.5
# Image saved as content/Monkeys/output_at_iteration_149.png
# Iteration 149 completed in 66s
# Start of iteration 150
# Current loss value: 8229921.5
# Image saved as content/Monkeys/output_at_iteration_150.png
# Iteration 150 completed in 66s
# Start of iteration 151
# Current loss value: 8204786.0
# Image saved as content/Monkeys/output_at_iteration_151.png
# Iteration 151 completed in 66s
# Start of iteration 152
# Current loss value: 8178268.0
# Image saved as content/Monkeys/output_at_iteration_152.png
# Iteration 152 completed in 66s
# Start of iteration 153
# Current loss value: 8153571.0
# Image saved as content/Monkeys/output_at_iteration_153.png
# Iteration 153 completed in 66s
# Start of iteration 154
# Current loss value: 8120046.5
# Image saved as content/Monkeys/output_at_iteration_154.png
# Iteration 154 completed in 66s
# Start of iteration 155
# Current loss value: 8090425.0
# Image saved as content/Monkeys/output_at_iteration_155.png
# Iteration 155 completed in 66s
# Start of iteration 156
# Current loss value: 8063423.5
# Image saved as content/Monkeys/output_at_iteration_156.png
# Iteration 156 completed in 66s
# Start of iteration 157
# Current loss value: 8038537.5
# Image saved as content/Monkeys/output_at_iteration_157.png
# Iteration 157 completed in 66s
# Start of iteration 158
# Current loss value: 8007443.5
# Image saved as content/Monkeys/output_at_iteration_158.png
# Iteration 158 completed in 66s
# Start of iteration 159
# Current loss value: 7980788.0
# Image saved as content/Monkeys/output_at_iteration_159.png
# Iteration 159 completed in 66s
# Start of iteration 160
# Current loss value: 7934003.0
# Image saved as content/Monkeys/output_at_iteration_160.png
# Iteration 160 completed in 66s
# Start of iteration 161
# Current loss value: 7900345.0
# Image saved as content/Monkeys/output_at_iteration_161.png
# Iteration 161 completed in 66s
# Start of iteration 162
# Current loss value: 7872020.5
# Image saved as content/Monkeys/output_at_iteration_162.png
# Iteration 162 completed in 66s
# Start of iteration 163
# Current loss value: 7842454.0
# Image saved as content/Monkeys/output_at_iteration_163.png
# Iteration 163 completed in 66s
# Start of iteration 164
# Current loss value: 7816186.0
# Image saved as content/Monkeys/output_at_iteration_164.png
# Iteration 164 completed in 66s
# Start of iteration 165
# Current loss value: 7791349.5
# Image saved as content/Monkeys/output_at_iteration_165.png
# Iteration 165 completed in 66s
# Start of iteration 166
# Current loss value: 7763826.0
# Image saved as content/Monkeys/output_at_iteration_166.png
# Iteration 166 completed in 66s
# Start of iteration 167
# Current loss value: 7730202.0
# Image saved as content/Monkeys/output_at_iteration_167.png
# Iteration 167 completed in 66s
# Start of iteration 168
# Current loss value: 7702331.0
# Image saved as content/Monkeys/output_at_iteration_168.png
# Iteration 168 completed in 66s
# Start of iteration 169
# Current loss value: 7676346.0
# Image saved as content/Monkeys/output_at_iteration_169.png
# Iteration 169 completed in 66s
# Start of iteration 170
# Current loss value: 7654903.0
# Image saved as content/Monkeys/output_at_iteration_170.png
# Iteration 170 completed in 66s
# Start of iteration 171
# Current loss value: 7634492.5
# Image saved as content/Monkeys/output_at_iteration_171.png
# Iteration 171 completed in 66s
# Start of iteration 172
# Current loss value: 7616451.0
# Image saved as content/Monkeys/output_at_iteration_172.png
# Iteration 172 completed in 66s
# Start of iteration 173
# Current loss value: 7593137.0
# Image saved as content/Monkeys/output_at_iteration_173.png
# Iteration 173 completed in 66s
# Start of iteration 174
# Current loss value: 7573150.0
# Image saved as content/Monkeys/output_at_iteration_174.png
# Iteration 174 completed in 66s
# Start of iteration 175
# Current loss value: 7550736.0
# Image saved as content/Monkeys/output_at_iteration_175.png
# Iteration 175 completed in 66s
# Start of iteration 176
# Current loss value: 7531946.0
# Image saved as content/Monkeys/output_at_iteration_176.png
# Iteration 176 completed in 66s
# Start of iteration 177
# Current loss value: 7509438.0
# Image saved as content/Monkeys/output_at_iteration_177.png
# Iteration 177 completed in 66s
# Start of iteration 178
# Current loss value: 7482435.5
# Image saved as content/Monkeys/output_at_iteration_178.png
# Iteration 178 completed in 66s
# Start of iteration 179
# Current loss value: 7456657.5
# Image saved as content/Monkeys/output_at_iteration_179.png
# Iteration 179 completed in 66s
# Start of iteration 180
# Current loss value: 7438464.0
# Image saved as content/Monkeys/output_at_iteration_180.png
# Iteration 180 completed in 66s
# Start of iteration 181
# Current loss value: 7419023.5
# Image saved as content/Monkeys/output_at_iteration_181.png
# Iteration 181 completed in 66s
# Start of iteration 182
# Current loss value: 7402590.5
# Image saved as content/Monkeys/output_at_iteration_182.png
# Iteration 182 completed in 66s
# Start of iteration 183
# Current loss value: 7385301.5
# Image saved as content/Monkeys/output_at_iteration_183.png
# Iteration 183 completed in 66s
# Start of iteration 184
# Current loss value: 7367376.5
# Image saved as content/Monkeys/output_at_iteration_184.png
# Iteration 184 completed in 66s
# Start of iteration 185
# Current loss value: 7337961.0
# Image saved as content/Monkeys/output_at_iteration_185.png
# Iteration 185 completed in 66s
# Start of iteration 186
# Current loss value: 7312914.5
# Image saved as content/Monkeys/output_at_iteration_186.png
# Iteration 186 completed in 66s
# Start of iteration 187
# Current loss value: 7290305.0
# Image saved as content/Monkeys/output_at_iteration_187.png
# Iteration 187 completed in 66s
# Start of iteration 188
# Current loss value: 7270411.0
# Image saved as content/Monkeys/output_at_iteration_188.png
# Iteration 188 completed in 66s
# Start of iteration 189
# Current loss value: 7254321.0
# Image saved as content/Monkeys/output_at_iteration_189.png
# Iteration 189 completed in 66s
# Start of iteration 190
# Current loss value: 7236167.5
# Image saved as content/Monkeys/output_at_iteration_190.png
# Iteration 190 completed in 66s
# Start of iteration 191
# Current loss value: 7214269.5
# Image saved as content/Monkeys/output_at_iteration_191.png
# Iteration 191 completed in 66s
# Start of iteration 192
# Current loss value: 7193670.5
# Image saved as content/Monkeys/output_at_iteration_192.png
# Iteration 192 completed in 66s
# Start of iteration 193
# Current loss value: 7175961.0
# Image saved as content/Monkeys/output_at_iteration_193.png
# Iteration 193 completed in 66s
# Start of iteration 194
# Current loss value: 7155874.5
# Image saved as content/Monkeys/output_at_iteration_194.png
# Iteration 194 completed in 66s
# Start of iteration 195
# Current loss value: 7141912.0
# Image saved as content/Monkeys/output_at_iteration_195.png
# Iteration 195 completed in 66s
# Start of iteration 196
# Current loss value: 7125618.5
# Image saved as content/Monkeys/output_at_iteration_196.png
# Iteration 196 completed in 66s
# Start of iteration 197
# Current loss value: 7109803.5
# Image saved as content/Monkeys/output_at_iteration_197.png
# Iteration 197 completed in 66s
# Start of iteration 198
# Current loss value: 7093696.5
# Image saved as content/Monkeys/output_at_iteration_198.png
# Iteration 198 completed in 66s
# Start of iteration 199
# Current loss value: 7078160.5
# Image saved as content/Monkeys/output_at_iteration_199.png
# Iteration 199 completed in 69s
# Start of iteration 200
# Current loss value: 7064123.0
# Image saved as content/Monkeys/output_at_iteration_200.png
# Iteration 200 completed in 66s
# Start of iteration 201
# Current loss value: 7048863.0
# Image saved as content/Monkeys/output_at_iteration_201.png
# Iteration 201 completed in 66s
# Start of iteration 202
# Current loss value: 7032105.5
# Image saved as content/Monkeys/output_at_iteration_202.png
# Iteration 202 completed in 66s
# Start of iteration 203
# Current loss value: 7015194.5
# Image saved as content/Monkeys/output_at_iteration_203.png
# Iteration 203 completed in 66s
# Start of iteration 204
# Current loss value: 7000623.0
# Image saved as content/Monkeys/output_at_iteration_204.png
# Iteration 204 completed in 66s
# Start of iteration 205
# Current loss value: 6989879.5
# Image saved as content/Monkeys/output_at_iteration_205.png
# Iteration 205 completed in 66s
# Start of iteration 206
# Current loss value: 6978295.5
# Image saved as content/Monkeys/output_at_iteration_206.png
# Iteration 206 completed in 66s
# Start of iteration 207
# Current loss value: 6962908.0
# Image saved as content/Monkeys/output_at_iteration_207.png
# Iteration 207 completed in 66s
# Start of iteration 208
# Current loss value: 6948001.0
# Image saved as content/Monkeys/output_at_iteration_208.png
# Iteration 208 completed in 66s
# Start of iteration 209
# Current loss value: 6936595.5
# Image saved as content/Monkeys/output_at_iteration_209.png
# Iteration 209 completed in 66s
# Start of iteration 210
# Current loss value: 6918158.0
# Image saved as content/Monkeys/output_at_iteration_210.png
# Iteration 210 completed in 66s
# Start of iteration 211
# Current loss value: 6901375.5
# Image saved as content/Monkeys/output_at_iteration_211.png
# Iteration 211 completed in 66s
# Start of iteration 212
# Current loss value: 6888181.5
# Image saved as content/Monkeys/output_at_iteration_212.png
# Iteration 212 completed in 66s
# Start of iteration 213
# Current loss value: 6874621.0
# Image saved as content/Monkeys/output_at_iteration_213.png
# Iteration 213 completed in 66s
# Start of iteration 214
# Current loss value: 6861235.0
# Image saved as content/Monkeys/output_at_iteration_214.png
# Iteration 214 completed in 66s
# Start of iteration 215
# Current loss value: 6847822.0
# Image saved as content/Monkeys/output_at_iteration_215.png
# Iteration 215 completed in 66s
# Start of iteration 216
# Current loss value: 6835593.5
# Image saved as content/Monkeys/output_at_iteration_216.png
# Iteration 216 completed in 66s
# Start of iteration 217
# Current loss value: 6823373.5
# Image saved as content/Monkeys/output_at_iteration_217.png
# Iteration 217 completed in 66s
# Start of iteration 218
# Current loss value: 6809916.5
# Image saved as content/Monkeys/output_at_iteration_218.png
# Iteration 218 completed in 66s
# Start of iteration 219
# Current loss value: 6796795.0
# Image saved as content/Monkeys/output_at_iteration_219.png
# Iteration 219 completed in 66s
# Start of iteration 220
# Current loss value: 6783842.0
# Image saved as content/Monkeys/output_at_iteration_220.png
# Iteration 220 completed in 66s
# Start of iteration 221
# Current loss value: 6772797.5
# Image saved as content/Monkeys/output_at_iteration_221.png
# Iteration 221 completed in 66s
# Start of iteration 222
# Current loss value: 6758554.5
# Image saved as content/Monkeys/output_at_iteration_222.png
# Iteration 222 completed in 67s
# Start of iteration 223
# Current loss value: 6745649.5
# Image saved as content/Monkeys/output_at_iteration_223.png
# Iteration 223 completed in 67s
# Start of iteration 224
# Current loss value: 6734203.0
# Image saved as content/Monkeys/output_at_iteration_224.png
# Iteration 224 completed in 67s
# Start of iteration 225
# Current loss value: 6722968.0
# Image saved as content/Monkeys/output_at_iteration_225.png
# Iteration 225 completed in 67s
# Start of iteration 226
# Current loss value: 6710804.5
# Image saved as content/Monkeys/output_at_iteration_226.png
# Iteration 226 completed in 67s
# Start of iteration 227
# Current loss value: 6699315.5
# Image saved as content/Monkeys/output_at_iteration_227.png
# Iteration 227 completed in 67s
# Start of iteration 228

# %% [markdown]
# # 8) Generar imágenes para distintas combinaciones de pesos de las losses. Explicar las diferencias. (Adjuntar las imágenes generadas como archivos separados.)
#
# Respuesta:
#
# # 9) Cambiar las imágenes de contenido y estilo por unas elegidas por usted. Adjuntar el resultado.
#
# Respuesta:
